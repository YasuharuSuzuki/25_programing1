# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/25_programing1/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 03_list・tuple・set

# %% [markdown]
# ## 用語の理解を問う問題
# - 以下の問題について、正解となる選択肢を出力してください
# ※4択問題は1回目の解答のみが有効です。何度も提出することは出来ませんので、ご注意ください。

# %% [markdown]
# ---

# %% [markdown]
# ### 🎲 四択問題11 リスト操作 (3点)
# - リストをコロン（：）区切りで value[start:end] のように使用してリストの部分列を抽出できる機能をなんというか？
#     📕 1. ストリップ（strip）
#     📗 2. スプリット（split）
#     📘 3. スライス（slice）
#     📙 4. リスト内包表記

# %%
# 正解を出力してください
print('3')
# Out:
# 3

# %% [markdown]
# ---
#
# ### ✅ 解説
#
# * Pythonには、
#   `value[start:end]` **のようにコロン（:）を使って** リストや文字列の一部分を取り出す便利な機能があります
#   この機能を **スライス（slice）** と呼びます。
#
#   * 👉 よって **正解は「3. スライス（slice）」** です。
#   * 課題では、11_list1/04スライス.ipnyb で取り扱っております
#
# * 他の選択肢
#
#   * **1. ストリップ（strip）**：文字列の前後の空白や改行を削除するメソッド
#   * **2. スプリット（split）**：文字列を区切り文字で分割するメソッド
#   * **4. リスト内包表記**：リストを簡潔に生成するための記法で、部分列の抽出ではない
#
# ---

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
# os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/25_programing1/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# sandbox実行用
# os.symlink("../../src", ".client", target_is_directory=True)
# !bash ./sandbox_setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "15_期末対策/03_list・set・tuple.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問11 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=11, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題12 値を変更できないオブジェクト (3点)
# - tupleのように値を変更できないオブジェクトのことをなんというか
#
#     📕 1. ミュータブル
#     📗 2. イテラブル
#     📘 3. イミュータブル
#     📙 4. クラス

# %%
# 正解を出力してください
print('3')
# Out:
# 3

# %% [markdown]
# ---
#
# ### ✅ 解説
#
# * Pythonでは、
#   **一度作成したあとに中身の値を変更できないオブジェクト** のことを
#   **イミュータブル（immutable）** と呼びます。
#
#   * 👉 よって **正解は「3. イミュータブル」** です。
#   * 課題では、13_tupleとset/01_タプルを作る.ipnyb でイミュータブルであることが触れられています
#   * ミュータブル・イミュータブルの説明は、12_list2/01複製と比較.ipnyb に詳しく説明されております
#
# * 他の選択肢
#
#   * **1. ミュータブル**：作成後に中身の値を変更できるオブジェクト（例：list、dict）
#   * **2. イテラブル**：for 文などで順番に取り出せるオブジェクトの性質
#   * **4. クラス**：オブジェクトの設計図となる概念で、値の変更可否を表す用語ではない
#
# ---

# %%
#@title 問12 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=12, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題13 set (3点)
#
# 以下のプログラムの出力結果を選べ
#
# ```python
# all_color = set(["赤","白","黄","紫","桃"])
# input_color = set({"赤","白","白","赤","白","黒"})
# print(len(all_color-input_color))
# ```
#
#    📕 1. {'紫', '黄'}
#    📗 2. {'桃', '黒, '黄'}
#    📘 3. 2
#    📙 4. 3

# %%
# 正解を出力してください
print('4')
# Out:
# 4

# %% [markdown]
# ---
#
# ### ✅ 解説
#
# * このプログラムは、集合（set）の差集合と len() の結果を求める問題です。
#   * all_color = {"赤","白","黄","紫","桃"}
#     → 要素数は 5。
#
#   * input_color = {"赤","白","白","赤","黒"}
#     → 要素数は 3。
#
#   * 差集合 all_color - input_color は、{"黄", "紫", "桃"} となるため
#     → 要素数は 3。
#
#   * 👉 よって **正解は「4. 3」** です。
#   * 課題では、13_tupleとset/03_セットの集合演算.ipnyb で説明されております
#
# * 他の選択肢
#
#   * 📕1. と 📗2. 集合の中身を答えているが、`print` しているのは `len()` の結果
#   * 📘3. 要素数が不足している（実際は 3 要素）
#
# ---

# %%
#@title 問13 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=13, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---
# ---
# ---

# %% [markdown]
# ## アルゴリズム問題

# %% [markdown]
# ### 🌷 アルゴリズム問題14 チューリップ5 (15点)
#
# #### 📝 問題文
# - ゆるるくんは、花壇に5本のチューリップの球根を植えました。色は赤、白、黄、桃、紫のいずれかです。
# - 球根の状態から購入したのですが、またもや何色かを気にせずに購入してしまったため、咲いてみるまで色がわかりません。
# - 実際に咲いたときの色に応じたゆるるくんの感想を出力してください。
# - 色の値が漢字で入力されます。入力は $ C_1 \quad C_2 \quad C_3 \quad C_4 \quad C_5 $ で与えられます。
# - 5本とも同じ色の場合は全部同じ色であることを出力してください。
#   - 例：全部赤の場合は「全部赤！」
# - すべての色が異なる場合は「キレイだなぁ〜」と出力してください。
# - 全て同じ色でもなく、かつ全て違う色でもない場合は、購入していない色を出力してください。
#   - 例：白と黄を購入していない場合は「白と黄が欲しいなぁ〜」

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 📘 制約
#
# $ Ci $は'赤','白','黄','桃','紫'のいずれかからなる文字

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🔢 入力
#
# 入力は以下の形式で標準入力から与えられます
#
# ---
# $ C_1 \quad C_2 \quad C_3 \quad C_4 \quad C_5 $
#
# ---
#
# - チューリップの色 $ C_i $ を受け取ります

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 📤 出力
#
# - 全て同じ色のときは「全部$ C_i $！」と出力してください。
# - 全て違う色のときは「キレイだなぁ〜」と出力してください。
# - 全て同じ色でもなく、かつ全て違う色でもない場合
#    - 購入していない色が1つの場合($ C_{n} $)は「$ C_{n} $が欲しいなぁ〜」と出力せよ。
#    - 購入していない色が2つの場合($ C_{n1}, C_{n2} $)は「$ C_{n1} $と$ C_{n2} $が欲しいなぁ〜」と出力せよ。
#    - 購入していない色が3つの場合($ C_{n1}, C_{n2}, C_{n3} $)は「$ C_{n1} $と$ C_{n2} $と$ C_{n3} $が欲しいなぁ〜」と出力せよ。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🧾 入力例1
# ---
# ```python
# 赤　赤　赤　赤　赤
# ```
# ---
#
# #### 🧪 出力例1
# ---
# ```python
# 全部赤！
# ```
# ---
#
# - 全て同じ色のため「全部赤！」と出力してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🧾 入力例2
# ---
# ```python
# 赤 白 黄 桃 紫
# ```
# ---
#
# #### 🧪 出力例2
# ---
# ```python
# キレイだなぁ〜
# ```
# ---
# - 全て違う色のため「キレイだなぁ〜」と出力してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🧾 入力例3
# ---
# ```python
# 赤 白 白 桃 紫
# ```
# ---
#
# #### 🧪 出力例3
# ---
# ```python
# 黄が欲しいなぁ〜
# ```
# ---
# - 全て同じ色でもなく、かつ全て違う色でもないため、未購入の色（黄）を用いて「黄が欲しいなぁ〜」と出力してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🧾 入力例4
# ---
# ```python
# 赤 白 白 桃 桃
# ```
# ---
#
# #### 🧪 出力例4
# ---
# ```python
# 黄と紫が欲しいなぁ〜
# ```
# ---
# - 全て同じ色でもなく、かつ全て違う色でもないため、未購入の色（黄、紫）を用いて「黄と紫が欲しいなぁ〜」と出力してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🧾 入力例5
# ---
# ```python
# 紫 白 紫 白 白
# ```
# ---
#
# #### 🧪 出力例5
# ---
# ```python
# 赤と黄と桃が欲しいなぁ〜
# ```
# ---
# - 全て同じ色でもなく、かつ全て違う色でもないため、未購入の色（赤、黄、桃）を用いて「赤と黄と桃が欲しいなぁ〜」と出力してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### ここ↓にPythonコードを記述してください

# %%
all_color = {'赤','白','黄','桃','紫'}
input_set1 = set(input().split())
if len(input_set1) == 1:
    print(f'全部{input_set1.pop()}！')
elif len(input_set1) == 5:
    print('キレイだなぁ〜')
else:
    print('{}が欲しいなぁ〜'.format("と".join(list(all_color - input_set1))))
# Out:
#  紫 白 紫 白 白
# 黄と赤と桃が欲しいなぁ〜

# %%
#@title 問14 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=14, button_name="アルゴリズム問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🏞️ 問15 つなわたりステージ10 (20点)
#
# #### 📝 問題文
# ゆるるくんはつなわたりのゲームで遊んでいます。ステージ10のルールは以下の通りです：
#
# ##### 川の対岸への距離
# - 川の対岸へつなが設置されています。川の対岸への距離Dは10m～20mです
#
# ##### プレイヤーの挙動
# - 1秒に1回、左キー(L)もしくは右キー(R)の入力が可能です
# - キー入力をしない(N)こともできます
# - ゆるるくんは1秒間に1m進みます
# - 左キーが入力されると、ゆるるくんは左方向に+1傾きます
# - 右キーが入力されると、ゆるるくんは右方向に+1傾きます
#
# ##### 風
# - ステージ10では風が吹きます
# - 1秒に1回、左方向(L)もしくは右方向(R)へ風が吹きます
# - 左向きの風を受けると、ゆるるくんは左方向に+1傾きます
# - 右向きの風を受けると、ゆるるくんは右方向に+1傾きます
#
# ##### 傾き
# - 傾いている方向と逆方向にキー入力、もしくは風が吹くと、傾きが-1されます
# - 左右どちらかの傾きが+3を超えると綱から落ちてしまいます
#
# ##### 求めたいもの
# 川の対岸への距離を整数D、ゆるるくんのキー入力を文字列K、風を文字列Aで与えられたとき、ステージ10をクリアできるかどうかを判定してください。

# %% [markdown]
# ---

# %% [markdown]
# ### 📘 制約
#
# - 10 ≤ D ≤ 20（川の対岸への距離）
# - K,A は 'L', 'R', 'N' のみからなる文字列

# %% [markdown]
# ### 🔢 入力
#
# 入力は以下の形式で標準入力から与えられます
#
# ---
#
# $ D $
# $ K $
# $ A $
#
# ---
# - $ D $ は川の対岸への距離
# - $ K $ はゆるるくんのキー入力
# - $ A $ はゆるるくんが受ける風

# %% [markdown]
# ---

# %% [markdown]
# ### 📤 出力
# - ステージクリアの場合：`GOAL`
# - 落下した場合：`YOU LOST`

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🧾 入力例1
# ---
# ```python
# 10
# RLRRNNLRLR
# NLLLRRLLNN
# ```
# ---
#
# #### 🧪 出力例1
# ---
# ```python
# GOAL
# ```
# ---
# - 左方向に+1傾いていますが、無事GOALできました。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🧾 入力例2
# ---
# ```Python
# 20
# NRLLLLLLRRLLRRLLLNLL
# LLLLNLNNLNRLRRNLNLLR
# ```
# ---
#
# #### 🧪 出力例2
# ---
# ```
# "YOU LOST"
# ```
# ---
# - 4秒目のキー入力"L"と風向き"L"で左側に+5傾き、崖下に落下となりました。

# %% [markdown]
# ---
# ---
# ### ここ↓にPythonコードを記述してください

# %%
# 入力を受け取る
D = int(input())
K = input()
A = input()

# 左右の傾きを管理する変数
tilt = 0  # 正: 右傾き、負: 左傾き

# 1文字ずつ処理
time = 0  # debug用
for action, air in zip(K,A):
    # キー入力
    match action:
        case 'L':  tilt -= 1
        case 'R':  tilt += 1
    
    # キー入力
    match air:
        case 'L':  tilt -= 1
        case 'R':  tilt += 1
    
    # 傾きチェック
    if abs(tilt) > 3:
        print("YOU LOST")
        #print(f"YOU LOST, tilt={tilt}, time={time}")  # これは動作確認用のprint()文です。途中経過を見たい時にコメントアウトを外して、変数の内容を確認します。
        break

    time += 1  # debug用
else:
    # breakせずに最後まで到達できた場合
    print("GOAL")
    #print(f"GOAL tilt={tilt}")  # これは動作確認用のprint()文です。途中経過を見たい時にコメントアウトを外して、変数の内容を確認します。
# Out:
#  20
#  NRLLLLLLRRLLRRLLLNLL
#  LLLLNLNNLNRLRRNLNLLR
# YOU LOST

# %%
#@title 問15 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=15, button_name="アルゴリズム問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### ⚐ アルゴリズム問題16 旗揚げゲーム (20点)
#
# #### 📝 問題文
# - ゆるるくんは旗揚げゲームをすることにしました。
# - 旗揚げゲームとは左右の手に赤い旗と白い旗をそれぞれ持ち、出される指示のとおりに旗を上げ下げするゲームです。
#
# - 例えば以下のような指示と上げ下げの動作をします。
#   - 「赤上げて」で赤の旗を上げ、「白上げて」で白の旗を上げます。
#   - 「赤上げないで」で赤の旗を下げて、「白下げない」で白の旗を上げます。
#
# - 4回指示をすると一区切りとなり、次に4回指示を出すと終了となります。
#
# - 4回x2回指示が出された後に、上げている旗を空白区切りで出力してください。
# - ただし、赤白両方下げている時は"どちらも上げない"と出力してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 📘 制約
#
# - 4回指示が2回繰り返されます。
# - 最初の4回分の指示は文字列で指定され、「、」（全角カンマ）で区切られています。
# - 1回の指示は以下の文字列で構成されています。
#   -　1文字目は「赤」or「白」
#   -　2文字目は「上」or「下」
#   -　3文字目以降は「げて」or「げない」or「げないで」のいずれか

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🔢 入力
#
# 入力は以下の形式で標準入力から与えられます
#
# ---
#
# $ S_1 $
# $ S_2 $
#
# ---

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 📤 出力
#
# ---
#
# "赤" or "白" or "赤 白" or "どちらも上げない"
#
# ---
#
# 上げている旗を出力して下さい。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🧾 入力例1
# ---
# ```python
# 赤上げて、白上げて、赤下げないで、白下げて
# 白上げない、赤下げて、赤下げないで、白上げて
# ```
# ---
#
# #### 🧪 出力例1
# ---
# ```python
# 赤 白
# ```
# ---
# - 両方の旗を上げている状態のため、"赤 白"と出力します。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🧾 入力例2
#
# ---
# ```python
# 赤下げて、白下げて、赤上げないで、白上げて
# 白下げない、赤下げて、赤上げないで、白下げて
# ```
# ---
#
# #### 🧪 出力例2
# ---
# ```python
# どちらも上げない
# ```
# ---
# - 両方の旗を下げている状態のため、"どちらも上げない"と出力します。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🧾 入力例3
# ---
# ```python
# 白下げない、赤下げて、赤上げないで、白下げて
# 赤下げて、赤上げない、白上げないで、白上げて
# ```
# ---
#
# #### 🧪 出力例3
# ---
# ```python
# 白
# ```
# ---
# - 白だけを上げている状態のため、"白"と出力します。

# %% [markdown]
# ---
# ---
# ### ここ↓にPythonコードを記述してください

# %%
# 2行の文字列をsplitしながら受け取ります
s = input().split('、') # 1行の文字列 → 4つの文字列のリストに変換
s += input().split('、') # 1行の文字列 → 4つの文字列のリストに変換 → 前のリストに追加

# 分解した８つの要素を、for文で回しながら解析していきます。
red = False # 赤フラグ。Trueのときに赤を上げている状態として判定するための変数です
white = False # 白フラグ。Trueのときに白を上げている状態として判定するための変数です
for s1 in s: # 8つの要素を回すループ
    if s1[1:].startswith('上げて') or s1[1:].startswith('下げない'): # 2文字目以降を抽出して '上げて' もしくは '下げない' を判定します。つまり上げている状態の判定ですね。startswith()を用いているのは'で'が後ろにつくケースを考慮しています
        if s1[0] == '赤': # 1文字目が赤なら
            red = True # 赤フラグを立てます。赤を上げている状態となります。
        else: # 1文字目が赤以外なら白しかないので
            white = True # 白フラグを立てます。白を上げている状態となります。
    elif s1[1:].startswith('下げて') or s1[1:].startswith('上げない'): # 2文字目以降を抽出して '下げて' もしくは '上げない' を判定します。つまり下げている状態の判定ですね。startswith()を用いているのは'で'が後ろにつくケースを考慮しています
        if s1[0] == '赤': # 1文字目が赤なら
            red = False # 赤フラグをOFFにします。赤を下げている状態となります。
        else: # 1文字目が赤以外なら白しかないので
            white = False # 白フラグをOFFにします。白を下げている状態となります。
#     print(red, white) # これは動作確認用のprint()文です。途中経過を見たい時にコメントアウトを外して、変数の内容を確認します。

# 赤/白を上げた判定を元にprint文を書きます。「赤 白」「赤」「白」「どちらも上げない」の4パターンを出力します。
if red and white:
    print('赤 白')
elif red:
    print('赤')
elif white:
    print('白')
else:
    print('どちらも上げない')
# Out:
#  赤上げて、白上げて、赤下げないで、白下げて
#  白上げない、赤下げて、赤下げないで、白上げて
# 赤 白

# %%
#@title 問15 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=15, button_name="アルゴリズム問題"))
