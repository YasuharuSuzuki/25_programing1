# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/25_programing1/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01_基本文法・if文

# %% [markdown]
# ## 用語の理解を問う問題
# - 以下の問題について、正解となる選択肢を出力してください
# ※4択問題は1回目の解答のみが有効です。何度も提出することは出来ませんので、ご注意ください。

# %% [markdown]
# ---

# %% [markdown]
# ### 例題1
# - 繰り返し文（ループ文）で使用する制御文を次から選択してください
#   📕 1. loop
#   📗 2. whole
#   📘 3. for
#   📙 4. if

# %%
# 正解例
print('3')
# Out:
# 3

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題1 文字列のメソッド(3点)
# - 文字が見つかった最初の位置を返すメソッドは次のどれか
#     📕 1. search
#     📗 2. strstr
#     📘 3. firstIndex
#     📙 4. find

# %%
# 正解を出力してください
print('4')
# Out:
# 4

# %% [markdown]
# ---
#
# ### ✅ 解説
#
# * Pythonの文字列には、
#   **指定した文字（または文字列）が最初に見つかった位置を返す**
#   `find()` メソッドがあります。
#
#   * 👉 よって **正解は「4. find」** です。
#   * 課題では、04組み込み関数/04文字列のメソッド.ipnyb で取り扱っております
#
# * 他の選択肢
#
#   * 1. **search**：文字列のメソッドとしては存在しない（正規表現 `re` モジュールには `search()` がある）
#   * 2. **strstr**：C言語で使われる関数名で、Pythonには存在しない
#   * 3. **firstIndex**：Pythonには定義されていないメソッド名
#
# ---

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
# os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/25_programing1/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# sandbox実行用
# os.symlink("../../src", ".client", target_is_directory=True)
# !bash ./sandbox_setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "15_期末対策/01_基本文法・if文.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問1 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=1, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題2 モジュール読み込み (3点)
# - randomモジュールからrandint関数のみを読み込む正しい方法を次から選びなさい
#     📕 1. import random.randint
#     📗 2. from random import randint
#     📘 3. import randint from random
#     📙 4. using random.randint

# %%
# 正解を出力してください
print('2')
# Out:
# 2

# %% [markdown]
# ---
#
# ### ✅ 解説
#
# - Pythonでは、
#   **特定のモジュールから関数だけを読み込みたい場合、**
#   `from モジュール名 import 関数名` という書き方を使います。
#
#   - 👉 よって **正解は「2. from random import randint」** です。
#   - 課題では、04組み込み関数/02モジュール読み込み.ipnyb で取り扱っております
#
# * 他の選択肢
#
#   📕 1. import random.randint：このような書き方はできない
#   📘 3. import randint from random：Pythonの構文として誤り
#   📙 4. using random.randint：Pythonには using という構文は存在しない
#
# ---

# %%
#@title 問2 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=2, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題3 字下げ (3点)
#
# - Pythonのプログラムにおいて、コードブロックの範囲を定義するために使用される空白文字による字下げのことを何というか？
#     📕 1. スペーシング
#     📗 2. インデント
#     📘 3. マージン
#     📙 4. タブ

# %%
# 正解を出力してください
print('2')
# Out:
# 2

# %% [markdown]
# ---
#
# ### ✅ 解説
#
# - Pythonでは、
#   **if文やfor文などのコードブロックの範囲を示すために、**
#   空白文字による字下げを使います。
#   この字下げのことを **インデント（indent）** と呼び、
#   Pythonでは **文法の一部として必須** になっています。
#
#   - 👉 よって **正解は「2. インデント」** です。
#   - 課題では、05if文/01if文_条件で処理を分岐する.ipnyb で取り扱っております
#
# * 他の選択肢
#
#   📕 1. **スペーシング** ：一般的に文字間や余白を指す言葉で、コードブロックの定義には使われない
#   📘 3. **マージン** ：主にレイアウトやデザインで使われる用語
#   📙 4. **タブ** ：字下げに使う文字の一種だが、字下げそのものの名称ではない
#
# ---

# %%
#@title 問3 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=3, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---
# ---
# ---
# ## アルゴリズム問題

# %% [markdown]
# ### 𓃠 アルゴリズム問題4 吾輩は (10点)
#
# #### 📝 問題文
#
# - ゆるるくんは名作の名言を真似できるプログラムを作成中です。
# - 動物名$S$を入力したら、吾輩は$S$である　と出力するプログラムを作成してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 📘 制約
#
# $
# S \qquad ※S は15文字までの文字列  \\
# $

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🔢 入力
#
# 入力は以下の形式で標準入力から与えられます
#
# ---
# $ S $
#
# ---
#
# ※input()１つで取得可能

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 📤 出力
#
# ---
#
# 吾輩は $ S $ である
#
# ---
#
# 名作の名言の一部を変えて出力してください。

# %% [markdown]
# ---
# ---
#
# #### 🧾 入力例1
# ---
# ```python
# サーバルキャット
# ```
# ---
#
# #### 🧪 出力例1
# ---
# ```python
# 吾輩はサーバルキャットである
# ```
# ---
# ※ 名作の名言の一部を変えて出力してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🧾 入力例2
#
# ---
# ```python
# トゲアリトゲナシトゲトゲ
# ```
# ---
# - 動物名を受け取ります。
#
# #### 🧪 出力例2
# ---
# ```python
# 吾輩はトゲアリトゲナシトゲトゲである
# ```
# ---
# - 名作の名言の一部を変えて出力してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### ここ↓にPythonコードを記述してください

# %%
s = input()
print(f"吾輩は{s}である")
# Out:
#  トゲアリトゲナシトゲトゲ
# 吾輩はトゲアリトゲナシトゲトゲである

# %%
#@title 問4 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=4, button_name="アルゴリズム問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🚅 アルゴリズム問題5 新幹線料金の計算 (10点)
#
# #### 📝 問題文
#
# 東海道新幹線（東京―新大阪間）の料金は以下の通りです：
#
# ##### 基本料金
# - のぞみ : 10000円
# - ひかり : 9000円
# - こだま : 8000円
#
# ##### 座席区分による変更
# - 指定席 : 基本料金
# - 自由席 : 基本料金から500円引き
# - グリーン車：基本料金に5000円追加
#
# 列車種別と座席区分が与えられた時、料金を計算するプログラムを作成してください。
# - 列車種別 : のぞみ、ひかり、こだま
# - 座席区分 : 指定席、自由席、グリーン車

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 📘 制約
#
# - $ T $ は3文字の文字列
# - $ S $ は3～5文字の文字列

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### 🔢 入力
# 入力は以下の形式で標準入力から与えられます
#
# ---
# $ T \qquad S $
#
# ---
#
# ※input()１つで取得可能

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### 📤 出力
#
# 料金を整数で出力

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### 🧾 入力例1
# ---
# ```python
# のぞみ　指定席
# ```
# ---
#
# ### 🧪 出力例1
# ---
# ```python
# 10000
# ```
# ---

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### 🧾 入力例2
# ---
# ```python
# ひかり　自由席
# ```
# ---
#
# ### 🧪 出力例2
# ---
# ```python
# 8500
# ```
# ---

# %% [markdown]
# ### 🧾 入力例3
# ---
# ```python
# こだま　グリーン車
# ```
# ---
#
# ### 🧪 出力例3
# ---
# ```python
# 13000
# ```
# ---

# %% [markdown]
# ---
# ---
# ### ここ↓にPythonコードを記述してください

# %%
# 入力
T, S = input().split()

# 基本料金を設定
train = 0
match T:
    case "のぞみ": train=10000
    case "ひかり": train=9000
    case "こだま": train=8000

# 座席区分による料金調整
sheet = 0
match S:
    case "自由席": sheet=-500
    case "グリーン車": sheet=+5000

# 出力
print(train+sheet)
# Out:
#  こだま　グリーン車
# 13000

# %%
#@title 問5 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=5, button_name="アルゴリズム問題"))
