# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/25_programing1/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 13-2 セット
# - セットはリストやタプル同様に複数の値をまとめて使う方法の１つです。
# - セットは集合を表し、ユニークな（重複のない）要素をまとめて保持します。
# - セットは集合演算を扱うことができます。（積集合や和集合を計算できます）。

# %% [markdown]
# ---

# %% [markdown]
# ### 🌐 セット 参考サイト
# #### [参考サイト1【Python早見表】セット](https://chokkan.github.io/python/10set.html)
#
# #### [参考サイト2【Python入門】セット](https://utokyo-ipp.github.io/appendix/2-set.html)

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 👨‍👨‍👧‍👧 サンプルプログラム3　setの作成・要素数の取得
# ### 大かっこからsetを作る
# - 要素に入れたい値をカンマ区切りで大かっこ { } で括って作ります

# %%
# setの作成
# 要素に入れたい値をカンマ区切りで大かっこ { } で括って作ります
color_type = {"赤","白","黄"}
color_type
# Out:
# {'白', '赤', '黄'}

# %%
# 数値でも作ることができます。
numbers = {1,2,3}
numbers
# Out:
# {1, 2, 3}

# %% [markdown]
# - 数字と文字列を混在させることも可能です。
# - 要素を,で区切って並べ、全体を{ }で囲んで作成します。

# %% [markdown]
# - setには順序がないため要素を取り出す時に [ ] で取り出すことができません

# %%
# 取り出そうとするとエラーになります
color_type[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [39], line 2
#       1 # 取り出そうとするとエラーになります
# ----> 2 color_type[0]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ### set()とリストからsetを作る
# - 組み込み関数set()にリストを渡して作ることもできます

# %%
color_type = set(["赤","白","黄"])
color_type
# Out:
# {'白', '赤', '黄'}

# %% [markdown]
# - range()を渡して順列を作ることもできます

# %%
numbers = set(range(1,10))
numbers
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %% [markdown]
# - listとは相互変換が可能です

# %%
# list()を使用してlist化することも可能
numbers_list = list(numbers)
print('numbers_list =', numbers_list)

# list化すると値を取り出すことができます。
numbers_list[3]
# Out:
# numbers_list = [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 4

# %% [markdown]
# ### setの要素は重複がない

# %%
color_type2 = {"赤","赤","黄"}
color_type2
# Out:
# {'赤', '黄'}

# %% [markdown]
# - 赤を２つ、黄色を１つ定義しましたが、赤が１つしかありません
# - セットはユニークな（重複のない）要素をまとめて保持するため、上記のように同じ値が重複して要素に追加されてもユニークな要素にまとめられて保持します。

# %% [markdown]
# ### 空集合はset()で作る
# - 大かっこ { } で作ると辞書になってしまうため、set()で作ります。

# %%
empty_set = set()
empty_set
# Out:
# set()

# %% [markdown]
# ### setの型を確認する

# %%
# 型を確認
print('type(color_type)={}'.format(type(color_type)))
# Out:
# type(color_type)=<class 'set'>

# %% [markdown]
# - set型となります。
# - list型やtuple型なども同様に複数の値をまとめて使う事ができますが、どれを使っているのかわからないときはこちらのようにtypeを使いましょう

# %% [markdown]
# ### 要素の数を確認する
# - len()を使います
# - リストやタプルと同じですね

# %%
# 要素の参照
print('len(numbers)=',len(numbers))
print('len(color_type)=',len(color_type))
print('len(color_type2)=',len(color_type2))
print('len(empty_set)=',len(empty_set))
# Out:
# len(numbers)= 9
# len(color_type)= 3
# len(color_type2)= 2
# len(empty_set)= 0

# %% [markdown]
# ---

# %% [markdown]
# ## 🍹 練習プログラム3 (8点)
#
# 1️⃣ setを作成してみましょう。題材は何でも良いです。
# 2️⃣ setの要素の数を出力してみましょう

# %%
# 1. setを作成してみましょう
# 入れる値は何でも良いですが、このNotebookのサンプルプログラムとは違う独自の値を入れましょう
# 変数名も独自のものに変えましょう

# ここにPythonプログラムを記述してください
fruits = {"apple", "banana", "orange", "apple"}
print("fruitsの中身:", fruits)
# Out:
# fruitsの中身: {'apple', 'banana', 'orange'}

# %%
# 2. 作成したsetの要素数を出力してみましょう

# ここにPythonプログラムを記述してください
print("fruitsの要素数:", len(fruits))
# Out:
# fruitsの要素数: 3

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/25_programing1/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# sandbox実行用
# os.symlink("../../src", ".client", target_is_directory=True)
# !bash ./sandbox_setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "13_tupleとset/02_セットの作り方・要素の追加と削除.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問3 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=3, button_name="練習プログラム"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 🕹️ サンプルプログラム4　setへの要素の追加・削除

# %% [markdown]
# ### 要素の追加
# - add()で追加できます
# - 後ほど紹介する集合演算でも追加できますが、ここでは扱いません。

# %%
color_type2
# Out:
# {'赤', '黄'}

# %%
color_type2.add('白')
color_type2
# Out:
# {'白', '赤', '黄'}

# %% [markdown]
# ### 要素の削除
# - remove(), discard(), clear(), pop()で削除できます
# - remove()では対象となる値が見つからない時はエラーが発生します。
# - discard()ではエラーは発生しません。
# - pop()ではどれか１つを削除しますが、setに順序がないため位置を指定するとTypeErrorになりますし、どれが削除されるのかがわからないためおすすめしません。

# %%
color_type2.remove('白')
color_type2
# Out:
# {'赤', '黄'}

# %%
# 対象となる値が見つかららない時はエラーが発生します。
color_type2.remove('黒')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 # 対象となる値が見つかららない時はエラーが発生します。
# ----> 2 color_type2.remove('黒')
#
# KeyError: '黒'

# %%
color_type2.discard('黄')
color_type2
# Out:
# {'赤'}

# %%
# 対象となる値が見つかららない時もエラーは発生しません。
color_type2.discard('黒')
color_type2
# Out:
# {'赤'}

# %%
# clear()ですべての値を削除します
color_type2.clear()
color_type2
# Out:
# set()

# %%
# pop()ではどれか１つを削除します。ただし、setには順序がないためどれが削除されるのかがわからず、おすすめしません。
color_type2.add('赤')
color_type2.add('白')
color_type2.add('黄')
color_type2.pop()
color_type2
# Out:
# {'白', '赤'}

# %%
# setのpopは位置が指定できないため、指定するとTypeErrorが出ます
color_type2.pop(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 # setのpopは位置が指定できないため、指定するとTypeErrorが出ます
# ----> 2 color_type2.pop(1)
#
# TypeError: set.pop() takes no arguments (1 given)

# %% [markdown]
# ---

# %% [markdown]
# ## 🎮 練習プログラム4 (8点)
# 1️⃣ まずは自由にsetを作成して、値を追加してみましょう
# 2️⃣ setの値を１つ削除してみましょう

# %%
# 1. まずは自由にsetを作成して、値を追加してみましょう
# 入れる値は何でも良いですが、このNotebookのサンプルプログラムとは違う独自の値を入れましょう

# ここにPythonプログラムを記述してください
subjects = {"Python", "数学", "英語"}

subjects.add("情報リテラシー")
print("追加後のsubjects:", subjects)
# Out:
# 追加後のsubjects: {'情報リテラシー', '英語', '数学', 'Python'}

# %%
# 2. setの値を１つ削除してみましょう

# ここにPythonプログラムを記述してください
subjects.remove("数学")
print("削除後のsubjects:", subjects)
# Out:
# 削除後のsubjects: {'情報リテラシー', '英語', 'Python'}

# %%
#@title 問4 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=4, button_name="練習プログラム"))
