# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/25_programing1/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 13-1 タプルを作る
# タプルはリスト同様に複数の値をまとめて使う方法の１つです。
# タプルはリストと違ってイミュータブルなオブジェクトですが、リストとほとんど同じ様に取り扱うことが出来ます。

# %% [markdown]
# ---

# %% [markdown]
# ### 🌐 タプル 参考サイト
# #### [参考サイト1【Python早見表】タプル](https://chokkan.github.io/python/07tuple.html)
#
# #### [参考サイト2【Python入門】タプル](https://utokyo-ipp.github.io/2/2-2.html#%E3%82%BF%E3%83%97%E3%83%AB-(tuple))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 🗄 サンプルプログラム1　タプルの作成・type・出力・参照・IndexError

# %%
# タプルの作成 (数字でも、文字列でも可)
kadai = (10, 9, 8, 9, 10, 9, 10, 11, 15, 7, 10, 9, 9, 10, 12) # 15回分の授業課題の点数
seiseki_kanji = ("不可","可","良","優","秀") # 漢字表記の成績

# %% [markdown]
# - 上記のように、数字でも、文字列でもタプルに追加することができます。
# - 数字と文字列を混在させることも可能です。
# - 要素を,で区切って並べ、全体を( )で囲んで作成します。

# %%
# 型を確認
print('type(kadai)={}'.format(type(kadai)))
# Out:
# type(kadai)=<class 'tuple'>

# %% [markdown]
# - tuple型となります。
# - list型や後で出てくるset型なども同様に複数の値をまとめて使う事ができますが、どれを使っているのかわからないときはこちらのようにtypeを使いましょう

# %%
# 要素の参照
print(f'seiseki_kanji[0]={seiseki_kanji[0]}')
print(f'seiseki_kanji[1]={seiseki_kanji[1]}')
print(f'seiseki_kanji[4]={seiseki_kanji[4]}')
# Out:
# seiseki_kanji[0]=不可
# seiseki_kanji[1]=可
# seiseki_kanji[4]=秀

# %% [markdown]
# - [ ]を使用してindexを指定すると、要素を取り出すことが出来ます。
# - indexはゼロスタートのため、5番目のデータを指定するには4を指定する必要があります。

# %%
# 要素の参照(マイナス値)
print(f'seiseki_kanji[-1]={seiseki_kanji[-1]}')
print(f'seiseki_kanji[-4]={seiseki_kanji[-4]}')
# Out:
# seiseki_kanji[-1]=秀
# seiseki_kanji[-4]=可

# %% [markdown]
# - 要素にマイナス値を指定すると後ろからのindex値で取得することが出来ます。
# - Pythonならではの便利な機能です。他言語では配列外参照エラーになることも多いので気をつけましょう。

# %%
# タプルの長さ
print('len(kadai)=',len(kadai))
print('len(seiseki_kanji)=',len(seiseki_kanji))
# Out:
# len(kadai)= 15
# len(seiseki_kanji)= 5

# %% [markdown]
# - tupleの長さはlen()で取得できます。

# %%
# タプルの長さを超えた要素を参照しようとするとエラー(IndexError)になる。
try:
    index = int(input()) # 入力値をintに変換してindexという変数で受け取る
    print(f'seiseki_kanji[{index}]={seiseki_kanji[index]}') # 漢字の成績を表示する
except IndexError as e: # IndexErrorの捕捉
    print('範囲外参照エラー', e)
# Out:
# 範囲外参照エラー tuple index out of range

# %% [markdown]
# ---

# %% [markdown]
# ## 🔗 練習プログラム1 (24点)
#
# 1️⃣ まずは自由にタプルを作成してみましょう。題材は何でも良いです。
# 2️⃣ タプルの型を出力してみましょう
# 3️⃣ 要素を参照してみましょう
# 4️⃣ 要素をマイナス値で指定して参照してみましょう
# 5️⃣ タプルの長さを出力してみましょう
# 6️⃣ 入力値 i を整数値で取得し、作成したタプルの要素 i を表示するプログラムを作成してみましょう
#   - ただし、IndexErrorのときは'範囲外参照エラー'と表示すること

# %%
# 1. タプルを作成してみましょう
# 入れる値は何でも良いですが、このNotebookのサンプルプログラムとは違う独自の値を入れましょう
# 変数名も独自のものに変えましょう

# ここにPythonプログラムを記述してください
expenses = (1200, 900, 1100, 1000, 4500, 3800, 800)
days = ("月曜日", "火曜日", "水曜日", "木曜日", "金曜日", "土曜日", "日曜日")

# %%
# 2. 作成したタプルの型を出力してみましょう
# 変数名を変えているはずですので、間違いないように型を出力してみましょう

# ここにPythonプログラムを記述してください
print('type(expenses)={}'.format(type(expenses)))
print('type(days)={}'.format(type(days)))
# Out:
# type(expenses)=<class 'tuple'>
# type(days)=<class 'tuple'>

# %%
# 3. 要素を参照してみましょう
# 変数名を変えているはずですので、間違いないように要素を出力してみましょう

# ここにPythonプログラムを記述してください
print(f'expenses[5]={expenses[5]}')
print(f'days[5]={days[5]}')
# Out:
# expenses[5]=3800
# days[5]=土曜日

# %%
# 4. 要素をマイナス値で指定して参照してみましょう
# 変数名を変えているはずですので、間違いないように要素を出力してみましょう

# ここにPythonプログラムを記述してください
print(f'expenses[-1]={expenses[-1]}')
print(f'days[-1]={days[-1]}')
# Out:
# expenses[-1]=800
# days[-1]=日曜日

# %%
# 5. タプルの長さを出力してみましょう
# 変数名を変えているはずですので、間違いないようにタプルの長さを出力してみましょう

# ここにPythonプログラムを記述してください
print('len(expenses)=',len(expenses))
print('len(days)=',len(days))
# Out:
# len(expenses)= 7
# len(days)= 7

# %%
# 6. 入力値 i を整数値で取得し、作成したタプルの要素 i を表示するプログラムを作成してみましょう
# 変数名を変えているはずですので、間違いないようにタプルの要素を出力してみましょう
# 入力値によってはIndexErrorが発生するため、そのときは'範囲外参照エラー'と表示しましょう

# ここにPythonプログラムを記述してください
try:
    index = int(input()) # 入力値をintに変換してindexという変数で受け取る
    print(days[index], "の出費は", expenses[index], "円です") # 曜日と出費を表示する
except IndexError as e: # IndexErrorの捕捉
    print('範囲外参照エラー', e)
# Out:
# 火曜日 の出費は 900 円です

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/25_programing1/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# sandbox実行用
# os.symlink("../../src", ".client", target_is_directory=True)
# !bash ./sandbox_setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "13_tupleとset/01_タプルを作る.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問1 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=1, button_name="練習プログラム"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 🗃️ サンプルプログラム2　タプルのアンパック・in演算子・sum(),max(),min()・比較

# %% [markdown]
# - タプルの各要素の値をカンマ区切りの変数に取り出すことができます（「アンパック」と呼ばれる）。
# - in 演算子やsum(),max(),min()などもリストと同様に使用することが出来ます
# - tupleは変数へ代入すると参照を保持するため、比較もほとんどリストと同様の挙動を示します。

# %%
# タプルの各要素の値をカンマ区切りの変数に取り出すことができます（「アンパック」と呼ばれる）。
fuka, ka, ryo, yu, shu = seiseki_kanji

# %%
fuka
# Out:
# '不可'

# %%
yu
# Out:
# '優'

# %%
# in演算子
'良' in seiseki_kanji
# Out:
# True

# %%
'悪' in seiseki_kanji
# Out:
# False

# %%
# sum()
sum(kadai)
# Out:
# 148

# %%
# max()
max(kadai)
# Out:
# 15

# %%
# min()
min(kadai)
# Out:
# 7

# %%
# 代入した変数との比較
a = (1,2,3)
b = a
print('a is b =', a is b) # tupleは変数へ代入すると参照を保持するため、インスタンスは同じ。つまりこちらはTrueになる
print('a == b =', a == b) # 値は当然同じのため、こちらもTrue
# Out:
# a is b = True
# a == b = True

# %%
# 逆順にしたtuple変数との比較
c = tuple(sorted(a, reverse=True)) # sorted()を使用して逆順のlistを作り、tuple()でタプル型に変換している
print('a is c =', a is c) # オブジェクトが異なるためこちらの比較はFalse
print('a == c =', a == c) # 値も異なるのでこちらの比較もFalseになります
# Out:
# a is c = False
# a == c = False

# %%
# 逆順にしたtuple変数同士の比較
d = (3,2,1)
print('c is d =', c is d) # インスタンスは異なるのでこちらはFalse
print('c == d =', c == d) # 値は一致するのでこちらはTrue
# Out:
# c is d = False
# c == d = True

# %% [markdown]
# ---

# %% [markdown]
# ## ⏏ 練習プログラム2 (16点)
#
# 1️⃣ まずは自由にタプルを作成して、アンパックでタプルの値を取り出してみましょう。題材は何でも良いです。
# 2️⃣ in演算子で比較してみよう
# 3️⃣ sum(),max(),min() のいずれかをリストと同様に使用してみよう
# 4️⃣ タプル同士を比較してみよう

# %%
# 1. アンパックでタプルの値を取り出してみよう
# 入れる値は何でも良いですが、このNotebookのサンプルプログラムとは違う独自の値を入れましょう
# 変数名も独自のものに変えましょう

# ここにPythonプログラムを記述してください
expenses = (1200, 900, 1100, 1000, 4500, 3800, 800)
days = ("月曜日", "火曜日", "水曜日", "木曜日", "金曜日", "土曜日", "日曜日")

getu, ka, sui, moku, kin, do, nichi = days
print(sui)
# Out:
# 水曜日

# %%
# 2. in演算子で比較してみよう
# 入れる値は何でも良いですが、このNotebookのサンプルプログラムとは違う独自の値を入れましょう
# 変数名も独自のものに変えましょう

# ここにPythonプログラムを記述してください

# in演算子
'木曜日' in days
# Out:
# True

# %%
# 3. sum(),max(),min()をリストと同様に使用してみよう
# 入れる値は何でも良いですが、このNotebookのサンプルプログラムとは違う独自の値を入れましょう
# 変数名も独自のものに変えましょう

# ここにPythonプログラムを記述してください
print("sum(expenses) =", sum(expenses))
# Out:
# sum(expenses) = 13300

# %%
# 4. タプル同士を比較してみよう
# 入れる値は何でも良いですが、このNotebookのサンプルプログラムとは違う独自の値を入れましょう
# 変数名も独自のものに変えましょう
# 比較の結果Trueとなる時、Falseとなる時それぞれについて記述してみましょう

# ここにPythonプログラムを記述してください
num1 = (100, 200, 300)
num2 = (300, 200, 100)
num2_rev = tuple(sorted(num2)) # sorted()を使用して逆順のlistを作り、tuple()でタプル型に変換している

print('num1 == num2 =', num1 == num2)
print('num1 == num2_rev =', num1 == num2_rev)
# Out:
# num1 == num2 = False
# num1 == num2_rev = True

# %%
#@title 問2 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=2, button_name="練習プログラム"))
