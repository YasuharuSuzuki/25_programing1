# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/25_programing1/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # アルゴリズム問題B
# - 5～6問目まであります。

# %% [markdown]
# ## 🏞️ アルゴリズム問題5　つなわたりステージ1 (20点)
#
# ### 📝 問題文
#
# ゆるるくんはつなわたりのゲームで遊んでいます。ステージ1のルールは以下の通りです：
#
# - つなの長さは20mです
# - 1秒に1回、左キー(L)もしくは右キー(R)の入力が可能です
# - キー入力をしない(N)こともできます
# - プレイヤーは1秒間に1m進みます
# - 左キーが入力されると、左方向に+1傾きます
# - 右キーが入力されると、右方向に+1傾きます
# - 傾いている方向と逆方向にキー入力すると、傾きが-1されます
# - 左右どちらかの傾きが+3を超えると綱から落ちてしまいます
#
# ゆるるくんのキー入力が文字列 S で与えられたとき、ステージ1をクリアできるかどうかを判定してください。
# ※そもそも左右キーを入力しなければGOALできるのですが、野暮なツッコミは辞めておきましょう・・・

# %% [markdown]
# ### 📘 制約
#
# - |S| = 20
# - S は 'L', 'R', 'N' のみからなる文字列

# %% [markdown]
# ### 🔢 入力
#
# 入力は以下の形式で標準入力から与えられる。
#
# ---
# S
#
# ---
#
# - 1行目にキー入力を表す文字列 S が与えられる

# %% [markdown]
# ### 📤 出力
#
# - ステージクリアの場合：`GOAL`
# - 落下した場合：`YOU LOST`

# %% [markdown]
# ---
# ---
#
# ### 🧾 入力例1
#
# ---
# ```
# NNLNRLRRLNNRLNLLRLNN
# ```
# ---
#
# ### 🧪 出力例1
# ---
# ```
# GOAL
# ```
# ---
#
# - 左方向に+2傾いていますが、無事GOALできました。

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### 🧾 入力例2
#
# ---
# ```
# NRLRLNRRLRNRNRLRLNRR
# ```
# ---
#
# ### 🧪 出力例2
# ---
# ```
# YOU LOST
# ```
# ---
#
# - 14文字目の"R"で右側に+4傾き、崖下に落下となりました。

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### ここ↓にPythonコードを記述してください

# %%
# Out:
#  NRLRLNRRLRNRNRLRLNRR
# YOU LOST

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/25_programing1/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "14_algorithm/02_アルゴリズム問題B.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問5 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=5, button_name="アルゴリズム問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 🃏 アルゴリズム問題6　ポーカーのストレート判定(20点)

# %% [markdown]
# ### 📝 問題文
# ポーカーの役の一つに「ストレート」があります。これは5枚のカードの数字が連続している場合を指します。
# ただし、絵柄（スート）は関係ありません。
#
# 例えば以下の場合はストレートです：
# - 8, 9, 10, J, Q （数値としては 8,9,10,11,12 と連続）
#
# 与えられた5枚のカードがストレートかどうかを判定するプログラムを作成してください。
#
# - J（ジャック）は11として扱います
# - Q（クイーン）は12として扱います
# - K（キング）は13として扱います
# - A（エース）は1として扱います

# %% [markdown]
# ### 📘 制約
#
# - 入力されるカードは重複しません
# - 各カードの数字は 1(A) ≤ 数字 ≤ 13(K) の範囲です
#   - 10,J,Q,K,A は連続した数として扱いません
# - スートは ♡（ハート）、♧（クラブ）、♤（スペード）、♢（ダイヤ）のいずれかです

# %% [markdown]
# ### 🔢 入力
#
# 入力は以下の形式で標準入力から与えられます。
#
# ---
#
# C1 C2 C3 C4 C5
#
# ---
#
# - スペース区切りで5枚のカードが与えられます
# - 各カードはスートと数字（または絵札）の組み合わせです

# %% [markdown]
# ### 📤 出力
#
# ストレートの場合は `YES` を、そうでない場合は `NO` を出力してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### 🧾 入力例1
#
# ---
# ```
# ♡10 ♧8 ♤J ♢9 ♧Q
# ```
# ---
#
# ### 🧪 出力例1
# ---
# ```
# YES
# ```
# ---
# - 8,9,10,11(J),12(Q) と連続しているため、ストレートです。

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### 🧾 入力例2
#
# ---
# ```
# ♡3 ♧8 ♤J ♢9 ♧Q
# ```
# ---
#
# ### 🧪 出力例2
# ---
# ```
# NO
# ```
# ---
#
# - カードの数字が連続していないため、ストレートではありません。

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### 🧾 入力例3
#
# ---
# ```
# ♡A ♧2 ♤3 ♢4 ♧5
# ```
# ---
#
# ### 🧪 出力例3
# ---
# ```
# YES
# ```
# ---
#
# - 1(A),2,3,4,5 と連続しているため、ストレートです。

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### ここ↓にPythonコードを記述してください

# %%
# Out:
#  ♡10 ♧8 ♤8 ♢9 ♧Q
# NO

# %%
#@title 問6 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=6, button_name="アルゴリズム問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## さらに得点をゲットするには・・・！

# %% [markdown]
# ### AtCoderによる加点
# - AtCoderのコンテストを解くと最大で30点まで加点されます
# - コーディング力もかなり向上するので一石二鳥でお得です！
# - 提出方法などわからないところは #atcoder チャンネルで聞いて、提出しましょう

# %% [markdown]
# <img src="https://img.atcoder.jp/assets/top/img/logo_bk.svg" width="500" height="400" style="padding: 10px;">

# %% [markdown]
# ### 🔰 [Python入門 AtCoder Programming Guide for beginners (APG4bPython)](https://atcoder.jp/contests/APG4bPython)
# - こちらはAtCoder入門者用の練習ページになります。
# - 皆さんは「第1章 基本文法」が解ければ十分ですが、まだ授業で扱っていない項目もありますのでご注意ください。
# - EX1〜EX13まで問題がありますが、解き終わって私宛に #atcoder チャンネルでご連絡いただいたら1問あたり課題点で5点ボーナス点を与えます。
# - 授業内容が簡単に感じる方はトライ頂くと良いでしょう。ご連絡頂く時はこちらのチャンネルでアカウント名をお知らせください。

# %% [markdown]
# ### 🐣 [AtCoder Daily Training](https://atcoder.jp/contests/adt_top)
# - こちらはAtCoderの練習用バーチャルコンテストになります。
# - 参加して問題が解けましたら、私宛にご連絡頂くと、解けた問題の点数/10を課題点で付与します。いちばん簡単なA問題で100点ですので、課題点の10点相当となり、かなり大きな加点になります。
# - 授業内容が簡単に感じる方は加点要素になりますのでトライ頂くと良いでしょう。プログラミングの練習にもなります。
# - ご連絡頂く時はこちらのチャンネルでアカウント名と、参加いただいたADTのURLをお知らせください。

# %% [markdown]
# ### 🏆 [AtCoder Beginner Contest](https://atcoder.jp/contests/)
# - コンテスト（ABC）も加点要素になりますので、参加いただいたらアカウントとABCのURLをお知らせください。
# - いちばん簡単なA問題で100点ですので、課題点の10点相当となり、かなり大きな加点になります。

# %% [markdown]
# ### 🤔 なぜAtCoderで加点するのか
#
# - 形式としてはアルゴリズム問題に近く、プログラミングの能力を向上させる効果があります
# - 課題と違って即座に自動で正解・不正解が判明するので非常に効率の良い練習ができます
# - 正解が出たら加点しますので、URLをお送りください
# - 問題内容としてはアルゴリズム問題の易しめの問題が1～2問、難しい問題と同じぐらいの難易度の問題が1～2問出ます
#   - AtCoderで `A問題` と言われる問題を中心に解きましょう。 `B問題`は解ける方がいるかもしれませんが、`C問題`以降はほとんど無理です。
#   - もっと難しい問題もありますが、そちらはやらなくて良いです（プロのエンジニアでも解くのが難しい問題がたくさん出ます）。

# %% [markdown]
# ### 👍 お得情報
#
# - 例年、プログラミングⅠで高得点を取る方は以下の傾向があります
#   - アルゴリズム問題をきちんと解いてた人は点数が高いです（当たり前ですが）
#   - AtCoderにトライいただいている方も総じて高得点ですね（数は少ないのですが、効果てきめんなので良い成績に結びつく方が多いです）
#   - 予習している方（前日までに課題を提出している）も高得点が多いです（これは指摘された減点内容を再提出することによって加点している効果が大きいです）
#   - まわりの人とわいわい話しながら問題を解いている（自分たちで考える力が身につきます。ただしコピペは実力つかないので辞めましょうね）
#   - できるかぎり自分の力で解きつつ、わからないところは放置せずにアシスタントや講師に質問している（出来ない問題を出来ないままにする人は点数が低い方が多いです）
#
# - プログラミングⅡで秀を取られた方は、毎回AtCoderを提出していた方が多くいました
#   - 加点になるのに加えて実力もつきますので、ぜひチャレンジしましょう
