# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/25_programing1/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # アルゴリズム問題

# %% [markdown]
# ## アルゴリズム問題にチャレンジしよう
#
# ### はじめに
# プログラミングの世界へようこそ！
# ここでは、さまざまなアルゴリズム問題に取り組むことで、論理的思考力とプログラミングスキルを磨いていきます。
#
# ### アルゴリズム問題とは
# アルゴリズム問題は、特定の課題や要求に対して、効率的で正確な解決方法（アルゴリズム）を考え、それをプログラムとして実装する問題です。
# これらの問題は、実際のプログラミングの現場で直面する課題を単純化し、核心となる部分に焦点を当てています。
#
# ### なぜアルゴリズム問題を解くのか
# 1. **論理的思考力の向上**: 問題を分析し、段階的に解決する力が身につきます。
# 2. **プログラミング言語の習得**: 実践的に言語の文法やライブラリの使い方を学べます。
# 3. **効率的なコード作成**: より最適な解法を考えることで、効率的なプログラミング技術が身につきます。
# 4. **問題解決能力の育成**: さまざまな制約の中で最適な解決策を見つける力が養われます。
#
# ### アプローチの仕方
# 1. **問題文の理解**: 与えられた問題をよく読み、要求されている事項を明確にしましょう。
# 2. **入力と出力の確認**: 与えられる入力と期待される出力を正確に把握しましょう。
# 3. **制約条件の確認**: 問題に付随する制約を理解し、それを満たす解法を考えましょう。
# 4. **アルゴリズムの設計**: 問題を解決するための手順を考え、擬似コードなどで整理しましょう。
# 5. **コーディング**: 設計したアルゴリズムを実際のプログラミング言語で実装しましょう。
# 6. **テストと改善**: サンプル入力で動作確認し、必要に応じて改善しましょう。
#
# ### さあ、始めましょう
# 期末試験やAtCoderではアルゴリズム問題がたくさん出ます！
# 以下の問題に取り組んで、プログラミングの力を磨いていきましょう。失敗を恐れず、トライ＆エラーを繰り返すことが上達の秘訣です。がんばってください！

# %% [markdown]
# ## サンプル問題　買い物割引判定問題
# プログラミングでは、日常生活のさまざまな状況を論理的に処理することができます。
# この問題では、スーパーマーケットの割引システムをモデル化し、条件分岐（if文）を使って適切な割引率を決定する方法を学びます。
#
# この問題を理解することで、以下のスキルを身につけることができます：
# 1. 入力値の受け取り方
# 2. 条件分岐（if, elif, else）の使い方
# 3. 比較演算子（<, >=）の使用方法
# 4. 段階的な条件設定の考え方
#
# 実際のビジネスロジックをプログラムで表現することで、プログラミングの実用的な側面を理解することができます。また、この問題は、より複雑な割引システムや価格計算のアルゴリズムへの入門としても役立ちます。
#
# それでは、以下の問題文をよく読んで、アルゴリズム問題を理解しましょう。

# %% [markdown]
# ### 問題文
# あるスーパーマーケットでは、買い物の合計金額に応じて以下のような割引を行っています：
#
# - 1000円未満：割引なし
# - 1000円以上3000円未満：5%割引
# - 3000円以上5000円未満：10%割引
# - 5000円以上：15%割引
#
# 買い物の合計金額が与えられたとき、適用される割引率を求めるプログラムを作成してください。

# %% [markdown]
# ### 制約
# - 入力される金額は0以上10000以下の整数
#
# ##### 制約について
# - 問題文中の「制約」は、あなたが作成するプログラムに課される制限ではありません。これは、入力として与えられる値の範囲や条件を示すものです。
#
# ##### 制約の意味
# - 制約は、プログラムに入力される可能性のある値の範囲を定義します。
# - 例えば、「Nは1以上100以下の整数」という制約は、入力値Nが1から100の間の整数であることを保証します。
#
# ##### なぜ制約が重要か
# 1. **エラー処理**: 制約外の入力を考慮する必要がないため、エラー処理を簡略化できます。
# 2. **最適化**: 入力値の範囲が分かることで、効率的なアルゴリズムを選択できます。
# 3. **テスト**: 制約に基づいてテストケースを作成し、プログラムの正確性を確認できます。
#
# ##### 制約の活用方法
# - 制約を理解し、それに基づいてアルゴリズムを設計しましょう。
# - 制約を満たす入力のみを想定してプログラムを作成します。
# - 制約外の入力に対する特別な処理は不要です。
#
# 制約を正しく理解することで、より効率的で堅牢なプログラムを作成することができます。問題に取り組む際は、必ず制約をよく確認してください。

# %% [markdown]
# ### 入力
# 入力は以下の形式で標準入力から与えられます。
#
# ---
# ```
# N
# ```
# ---
#
# - Nは買い物の合計金額を表す整数（0 ≤ N ≤ 10000）

# %% [markdown]
# ### 出力
# 適用される割引率を整数で出力してください。単位（%）は不要です。

# %% [markdown]
# ### 入力例1
# ---
# ```
# 2500
# ```
# ---
#
# ### 出力例1
# ---
# ```
# 5
# ```
# ---

# %% [markdown]
# ### 入力例2
# ---
# ```
# 4999
# ```
# ---
#
# ### 出力例2
# ---
# ```
# 10
# ```
# ---

# %% [markdown]
# ### 入力例3
# ---
# ```
# 7000
# ```
# ---
#
# ### 出力例3
# ---
# ```
# 15
# ```
# ---

# %% [markdown]
# ### ここ↓にPythonコードを記述してください

# %%
# 買い物金額から割引率を判定するプログラム

# 標準入力から買い物金額を受け取る
amount = int(input())

# 金額に応じて割引率を判定
if amount < 1000:
    discount = 0
elif amount < 3000:
    discount = 5
elif amount < 5000:
    discount = 10
else:
    discount = 15

# 結果を出力
print(discount)

# %% [markdown]
# ### サンプル問題は以上です
# - どうでしょう？理解できましたでしょうか？
# - AtCoderなどの競技プログラミングでは、このような問題が出題されるためプログラミング能力向上に役立ちます。一番簡単な問題だけでも良いので解いてみると良いでしょう
#
# ### 問題を解いてみよう！
# - 引き続き問題文を解いてみましょう!

# %% [markdown]
# ---
# ---
# ---
# ---

# %% [markdown]
# ## 問8　季節の判定 (10点)

# %% [markdown]
# ### 問題文
# あなたは、入力された月から季節を判定するプログラムを作成しています。
# 日本の季節は以下のように定義されます：
#
# - 春：3月、4月、5月
# - 夏：6月、7月、8月
# - 秋：9月、10月、11月
# - 冬：12月、1月、2月
#
# 1から12までの整数が入力されたとき、対応する季節を出力してください。

# %% [markdown]
# ### 制約
# - 入力される値は1以上12以下の整数

# %% [markdown]
# ### 入力
# 入力は以下の形式で標準入力から与えられます。
#
# ---
# ```
# N
# ```
# ---
#
# - Nは月を表す整数（1 ≤ N ≤ 12）

# %% [markdown]
# ### 出力
# 対応する季節を一行で出力してください。
# 春、夏、秋、冬のいずれかを出力します。

# %% [markdown]
# ### 入力例1
# ---
# ```
# 5
# ```
# ---
#
# ### 出力例1
# ---
# ```
# 春
# ```
# ---

# %% [markdown]
# ### 入力例2
# ---
# ```
# 11
# ```
# ---
#
# ### 出力例2
# ---
# ```
# 秋
# ```
# ---

# %% [markdown]
# ### 入力例3
# ---
# ```
# 1
# ```
# ---
#
# ### 出力例3
# ---
# ```
# 冬
# ```
# ---

# %%
# 月から季節を判定するプログラム

# input()で月を受け取る

# 月に応じて季節を判定

# 結果を出力

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/25_programing1/feature/add_class01/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "05_if文/03_アルゴリズム問題.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問8 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=8))
