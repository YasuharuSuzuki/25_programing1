# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/25_programing1/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 10-1 例外とtry文の基本
# エラーが発生したときの処理を記述する

# %% [markdown]
# ## try文 参考サイト
# ### [参考サイト1 【Python早見表】 例外の補足](https://chokkan.github.io/python/14exception.html)
#
# ### [参考サイト2  Pythonの例外処理（try, except, else, finally）](https://note.nkmk.me/python-try-except-else-finally/)

# %% [markdown]
# ## エラーの発生
# - 実行中に様々なエラーが発生します
# - 発生するエラーと、その補足方法について学びましょう

# %% [markdown]
# ---

# %% [markdown]
# ## サンプルプログラム1　⚠️　ゼロ除算エラー

# %% [markdown]
# ### ⚠️　ゼロ除算エラー（例外）の発生
# - 入力値で9999を除算するプログラムです
# - ゼロを入力するとゼロ除算エラー（ZeroDivisionError）が発生します
#   - [ゼロ除算とは(wikiより抜粋)](https://ja.wikipedia.org/wiki/%E3%82%BC%E3%83%AD%E9%99%A4%E7%AE%97)
#     - ゼロ除算（ゼロじょさん、英語: division by zero）とは、0で除す割り算のことである。このような除算は除される数をaとするならば、形式上は a/0と書くことができるが、数学において、このような式を矛盾なく定義することはできない。
# コンピュータの数値計算においてゼロ除算が発生した場合、無限大というシンボルで置き換えられるか、発生した時点で処理が破綻する（システムエラーとなる）かのどちらかである。
#   - Pythonの場合はZeroDivisionErrorという例外が発生します。
# - 1などの数値を入力すると

# %%
divider = int(input())
divided = 9999 / divider
print(f"divided={divided:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 divider = int(input())
# ----> 2 divided = 9999 / divider
#       3 print(f"divided={divided}")
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ---
#
# ### 🖐　try 〜 except 節
# - try 〜 except 節を使用すると発生した例外を補足できます

# %%
try:
    divider = int(input())
    divided = 9999 / divider
    print(f"divided={divided:.2f}")
except ZeroDivisionError as e:
    print('ゼロ除算発生！！！')
# Out:
# ゼロ除算発生！！！

# %% [markdown]
# ---
# ### 🐣 動作を確認しよう！
# - 0を入力して ZeroDivisionError が発生することを確認しましょう
#   - 「ゼロ除算発生」と出力されることも確認しましょう
# - 1を入力して、divided=9999.0 と出力されることを確認しましょう
#   - 正常終了しているためexcept節は実行されません。
# - ”突然の死！”を入力して、ValueError例外が発生することを確認しましょう
#   - 異常終了していますが、ZeroDivisionErrorではないためexcept節は実行されません。

# %% [markdown]
# ---

# %% [markdown]
# ## 📝　練習プログラム1 (10点)
# - `input()` を使って、**整数値 N と整数値 M を空白区切りで入力** として受け取ってください
# - `N ÷ M` を計算し、その結果を変数に格納しましょう
#
# - ゼロ除算が発生した場合は
#   `ゼロ除算発生！！！`
#   と表示してください
#
# - ゼロ除算が発生しなかった場合は、計算結果を `R` として
#   `divided=R`
#   の形式で表示してください(小数点以下2桁まで)

# %%
# Out:
# ゼロ除算発生！！！

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/25_programing1/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "10_try文/01_例外とtry文の基本.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問1 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=1, button_name="練習プログラム"))

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## サンプルプログラム2 ⚠️　ValueError
# - 数値に変換できない文字列をintに渡すとValueErrorが発生します。
# - ValueErrorを補足するプログラムは以下のようになります。

# %%
try:
    divider2 = int(input())
    divided2 = 9999 / divider2
    print(f"divided2={divided2:.2f}")
except ValueError as e:
    print('ValueError発生！！！')
# Out:
# ValueError発生！！！

# %% [markdown]
# ---
# ### 🌱 動作を確認しよう！
# - `突然の死！` を入力して、ValueError例外が発生することを確認しましょう
#   - "ValueError発生！！！"と出力されることも確認しましょう
# - 1を入力して、divided2=9999.0 と出力されることを確認しましょう
#   - 正常終了しているためexcept節は実行されません。

# %% [markdown]
# ---

# %% [markdown]
# ## 📝　練習プログラム2 (10点)
# - `input()` を使って、**整数値 N と整数値 M を空白区切りで入力** として受け取ってください
# - `N ÷ M` を計算し、その結果を変数に格納しましょう
#
# - ”突然の死！”を入力して、ValueError例外が発生した場合は
#   `ValueError発生！！！`
#   と表示してください
#
# - ゼロ除算が発生しなかった場合は、計算結果を `R` として
#   `divided2=R`
#   の形式で表示してください(小数点以下2桁まで)

# %%
# Out:
# ValueError発生！！！

# %%
#@title 問2 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=2, button_name="練習プログラム"))

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## ⚠️ サンプルプログラム3　範囲外参照エラー
# ### 💁‍♀️ 範囲外参照エラーとは
# - `存在しない場所（番号）を指定してデータ` を取り出そうとしたときに発生するエラーです。
# - Pythonでは、主に `文字列` や `リスト（配列）` を扱うときに起こります。
#
# ### 🔍 具体例

# %%
alphabets = "abc"
char = alphabets[3]
print(f"char={char}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 2
#       1 alphabets = "abc"
# ----> 2 char = alphabets[3]
#       3 print(f"char={char}")
#
# IndexError: string index out of range

# %% [markdown]
# ---
#
# ### 🐣 動作を確認しよう！
#
# このプログラムでは、 `char` の中に **3番目の要素** を取り出そうとしています。
#
# しかし、
# - 要素の番号は **0から始まる**
# - この文字列にある番号は **0, 1, 2** まで
#
# そのため、存在しない番号を指定してしまい
# 👉 範囲外参照エラー（IndexError）が発生します。

# %% [markdown]
# ---

# %% [markdown]
# ## 📝　練習プログラム3 (10点)
# - `input()` を使って、**文字列 S と整数値 N を空白区切りで入力** として受け取ってください
# - 文字列 S の N 番目の文字を取り出し、その結果を変数に格納しましょう
#
# - Nが文字列 S の範囲外の場合は、except 節で IndexError を補足し、
#   `IndexError発生！！！`
#   と表示してください
#
# - 範囲外参照エラーが発生しなかった場合は、取得した文字を `C` として
#   `char3=C`
#   の形式で表示してください

# %% [markdown]
# ---

# %%
# Out:
# IndexError発生！！！

# %%
#@title 問3 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=3, button_name="練習プログラム"))

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## ⚠️　サンプルプログラム4 複数のexcept節
# - except節を複数記述することで例外の種類を複数に振り分けることが出来ます。
# - 0を入力するとゼロ除算、文字列を入力するとValueErrorを補足するプログラムは以下のようになります。

# %%
try:
    divider4 = int(input())
    divided4 = 9999 / divider4
    print(f"divided4={divided4}")
except ZeroDivisionError as e:
    print('ゼロ除算発生！！！')
except ValueError as e:
    print('ValueError発生！！！')
# Out:
# ValueError発生！！！

# %% [markdown]
# ---
# ### 🐫 動作を確認しよう！
# - 0を入力して ZeroDivisionError が発生することを確認しましょう
#   - "ゼロ除算発生！！！"と出力されることも確認しましょう
# - 1を入力して、divided2=9999.0 と出力されることを確認しましょう
#   - 正常終了しているためexcept節は実行されません。
# - ”突然の死！”を入力して、ValueError例外が発生することを確認しましょう
#   - "ValueError発生！！！"と出力されることも確認しましょう

# %% [markdown]
# ---

# %% [markdown]
# ## 📝　練習プログラム4 (10点)
# - ZeroDivisionErrorとValueErrorをexceptするプログラムを書いてみましょう
#
# - `input()` を使って、**整数値 N と整数値 M を空白区切りで入力** として受け取ってください
#
# - `N ÷ M` を計算し、その結果を変数に格納しましょう
#
# - ゼロ除算が発生した場合は
#   `ゼロ除算発生！！！`
#   と表示してください
#
# - ゼロ除算が発生しなかった場合は、計算結果を `R` として
#   `divided4=R`
#   の形式で表示してください
#
# - 文字列を入力して、ValueError例外が発生した場合
#   `ValueError発生！！！`
#   と表示してください(小数点以下2桁まで)

# %%
# Out:
# ゼロ除算発生！！！

# %%
#@title 問4 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=4, button_name="練習プログラム"))
