# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/25_programing1/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 03_用語の理解

# %% [markdown]
# ## 用語の理解を問う問題
# - 以下の問題について、正解となる選択肢を出力してください
# ※4択問題は1回目の解答のみが有効です。何度も提出することは出来ませんので、ご注意ください。

# %% [markdown]
# ---

# %% [markdown]
# ### 例題1
# - Python の型の一種で、整数値を表す型は次のうちどれか
#   1. int
#   2. float
#   3. str
#   4. and

# %%
# 正解例
print('1')
# Out:
# 1

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題8 例外処理 (3点)
#
# - 以下のプログラムで、input()で `11` と入力したときに、print()で出力される文字列はどれか？
#
# ---
#
# ```python
# try:
#     i = int(input())
#     print(8888 / i)
#     print("okikokudai"[i])
# except ZeroDivisionError as e:
#     print('ゼロ除算が発生しました')
# except IndexError as e:
#     print('範囲外参照エラーが発生しました')
# else:
#     print('エラー発生なし！')
# finally:
#     print('例外処理を終了します')
# print("このプログラムを正常終了します")
# ```
#
# ---

# %% [markdown]
# #### 📕 1.
# ```python
# ゼロ除算が発生しました
# 例外処理を終了します
# このプログラムを正常終了します
# ```
# ---

# %% [markdown]
# #### 📗 2.
# ```python
# 808.0
# 範囲外参照エラーが発生しました
# 例外処理を終了します
# このプログラムを正常終了します
# ```
# ---

# %% [markdown]
# #### 📘 3.
# ```python
# 808.0
# a
# エラー発生なし！
# 例外処理を終了します
# このプログラムを正常終了します"
# ```
# ---

# %% [markdown]
# #### 📙 4.
# ```python
# 例外処理を終了します
# ```
# ---

# %%
# 正解を出力してください
print('')

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/25_programing1/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "10_try文/03_用語の理解.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問8 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=8, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題9 例外 (3点)
# - Pythonで65535/0を計算した時に発生する例外を次から選べ
#     📕 1. IndexError
#     📗 2. DivisionZeroError
#     📘 3. ArrayIndexOutOfBoundsError
#     📙 4. ZeroDivisionError

# %%
# 正解を出力してください
print('')

# %%
#@title 問9 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=9, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題10 try 〜 else (3点)
# - try文のelseブロックに関する説明として、正しいものを選びなさい
#     📕 1. elseブロックは例外が発生した場合のみ実行される
#     📗 2. elseブロックはfinallyブロックの後に実行される
#     📘 3. elseブロックは必ずexceptブロックの前に記述する必要がある
#     📙 4. elseブロックはtryブロックで例外が発生しなかった場合に実行される

# %%
# 正解を出力してください
print('')

# %%
#@title 問10 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=10, button_name="四択問題"))
