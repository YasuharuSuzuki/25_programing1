# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/25_programing1/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 6-1 while文の基本とbreak
# 条件が満たされている間繰り返すwhile文と、ループを抜けるbreak

# %% [markdown]
# ## while文 参考サイト
# ### [参考サイト1 【Python早見表】 while文（条件付き反復）](https://chokkan.github.io/python/03control.html#while)
# - while文、continue文、break文、while-else文が簡単にわかりやすく説明されています。
#
# ### [参考サイト2 【Python入門】 while文による繰り返し](https://utokyo-ipp.github.io/3/3-2.html#while%E6%96%87%E3%81%AB%E3%82%88%E3%82%8B%E7%B9%B0%E3%82%8A%E8%BF%94%E3%81%97)
# - こちらはfor文を中心に解説されているのでfor文を学んでから見ると良いでしょう。練習問題もあります。

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## while文
# ### while文とは？
# - 条件に応じて繰り返し処理を実行するにはwhile文を使います。
# - [Python早見表の説明](https://chokkan.github.io/python/03control.html#while)
# - 次回学ぶfor文も同じ繰り返し処理ですが、私はfor文の方が使用回数は多いと思います。
#   - 使った回数をカウントしたわけではありませんが、繰り返し回数が明確になっていない処理ではwhileを使用することが多い気がします。
#   - 逆に繰り返し回数が明確になっている処理（AIの学習用画像の一括読み込みや、AIの学習処理など）はfor文を使うことが多いです。

# %% [markdown]
# ---

# %% [markdown]
# ### サンプルプログラム1　while文
# - countを0で初期化し、5回繰り返すプログラムを作成してみましょう

# %%
print("while開始！")
num = 0
while num < 5:
    print(f"while繰り返し中！ (count={num})")
    num += 1
print("while終了！")
# Out:
# while開始！
# while繰り返し中！ (count=0)
# while繰り返し中！ (count=1)
# while繰り返し中！ (count=2)
# while繰り返し中！ (count=3)
# while繰り返し中！ (count=4)
# while終了！

# %% [markdown]
# ### 説明
# - ```while開始!``` でプログラムを開始しています
# - countが5になるまでの間、```while繰り返し中！``` が実行されます。
# - countが5になると条件が満たされなくなり、whileループを抜けて ```while終了！``` と表示されます

# %% [markdown]
# ---

# %% [markdown]
# ### 練習プログラム1 (15点)
# - input()でループ回数を数字で受け取り、その回数分ループするプログラムを作成しましょう
#   - 最初に```while開始！ (loop_count=n)``` と出力します。ループ回数も表示しましょう。（nのところは実際のループ数）
#   - countがループ回数になるまでの間、```while繰り返し中！ (count=n)``` を出力します。（nのところは実際のループした回数）
#   - countがループ回数に達すると条件が満たされなくなり、whileループを抜けて ```while終了！``` と表示しましょう。
# - サンプルプログラム１をベースに開始や繰り返し中、終了などを表示してみましょう！

# %% [markdown]
# #### こちら↓にプログラムを記述しましょう

# %%
# Out:
# while開始！ (loop_count=6)
# while繰り返し中！ (count=0)
# while繰り返し中！ (count=1)
# while繰り返し中！ (count=2)
# while繰り返し中！ (count=3)
# while繰り返し中！ (count=4)
# while繰り返し中！ (count=5)
# while終了！

# %% [markdown]
# ### 動作確認
# - 最初にinputでループ回数を取得します。
# - ```while開始！ (loop_count=n)``` でプログラムを開始します。その時にループ回数も表示しましょう
# - countがループ回数になるまでの間、```while繰り返し中！ (count=n)``` が実行されます。
# - countがループ回数に達すると条件が満たされなくなり、whileループを抜けて ```while終了！``` と表示されます
# - マイナス値を入力すると１回も実行されないことも確認してみましょう
# - 1万など大きな値を入力すると実行に時間がかかることも確認しましょう（計算量を意識しましょう）

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/25_programing1/feature/add_class01/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "06_while文/01_while文の基本とbreak.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問1 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=1))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## break文
# - while文による繰り返し実行中にbreak文を実行すると、以降の処理を実行せずに繰り返しを終了します。
# - 終了条件をループ文中に好きなだけ追加できるため、比較的よく使用します。

# %% [markdown]
# ---

# %% [markdown]
# ### サンプルプログラム2　break文
# - 変数 `num` を `2` で初期化し、whileループで `1` ずつカウントアップします。
# - while文の途中のif文で、`num` 変数が `6` 以上になるかどうかを確認しています
# - `num` が `6` になるとbreak文を実行し、繰り返しを終了します

# %%
print("while開始！")
num = 2
while num < 10:
    print(f"while繰り返し中！ (num={num})")
    if num >= 6:
        print(f"break実行！ループを抜けます (num={num})")
        break
    num += 1
print(f"while終了！ (num={num})")
# Out:
# while開始！
# while繰り返し中！ (num=2)
# while繰り返し中！ (num=3)
# while繰り返し中！ (num=4)
# while繰り返し中！ (num=5)
# while繰り返し中！ (num=6)
# break実行！ループを抜けます (num=6)
# while終了！ (num=6)

# %% [markdown]
# ### 説明
# - `while開始!` でプログラムを開始しています
# - `num` が `6` になるまでの間、`while繰り返し中！ (num=n)` が実行されます。
# - `num` が `6` になるとif文の中が実行され、`break実行！ループを抜けます (num=n)` と表示したあと<b>break文を実行</b>してループを抜けます。
# - whileループを抜けたあと `while終了！ (num=n)` と表示します。

# %% [markdown]
# ---

# %% [markdown]
# ### 練習プログラム2 (15点)
# - input()で初期値、ループ終端番号、break番号を空白区切りで受け取り、サンプルプログラム２のように表示するプログラムを作成してみましょう
#   - 最初に`while開始！ (init_num=n, loop_end=n, break_num=n)` と出力します。初期値とループ終端番号、break番号も表示しましょう。（nは実際の初期値とループ終端番号とbreak番号）
#   - `num` がループ終端番号になるまでの間、`while繰り返し中！ (num=n)` を出力します。（nは現在の数値）
#   - `num` が `break_num` になるとif文の中が実行され、`break実行！ループを抜けます (num=n)` と表示したあと<b>break文を実行</b>してループを抜けましょう。
#   - breakしない場合は `num` を1つカウントアップしましょう。
#   - `num` がループ終端番号に達するとループ条件が満たされなくなり、whileループを抜けます。
#   - while条件を満たさなくなった場合、またはbreak文によりwhileループを抜けたら、 `while終了！ (num=n)` と表示しましょう。

# %% [markdown]
# #### 空白区切りの整数値の受取り
# - 空白区切りの整数値を受け取るには `map(int,input().split())` を使用しましょう。
# - この処理は、空白区切りの文字列を空白で分割し、整数値に変換する処理になります。
# - 以下のように処理を分けて考えると理解しやすいです
#
# ```python
# str_value = input()  # 文字列を受け取る（例: 0 5 3）
# str_list = str_value.split()  # split()関数を使用して空白で値を分割し、リストという複数の値を格納可能な形に変換します（リストについては後の章で詳しく扱います）
# int_list = map(int,str_list)  # map()関数を使用して、リストをすべてintに変換します
# init_num, loop_end, break_num = int_list  # アンパック、という機能でリスト内の複数の整数値を、各変数に格納します
# ```
# - 上記の処理を１行で記述すると `init_num, loop_end, break_num = map(int,input().split())` となります。

# %% [markdown]
# #### こちら↓にプログラムを記述しましょう

# %%
# Out:
# while開始！ (init_num=11, loop_end=25, break_num=18)
# while繰り返し中！ (num=11)
# while繰り返し中！ (num=12)
# while繰り返し中！ (num=13)
# while繰り返し中！ (num=14)
# while繰り返し中！ (num=15)
# while繰り返し中！ (num=16)
# while繰り返し中！ (num=17)
# while繰り返し中！ (num=18)
# break実行！ループを抜けます (num=18)
# while終了！ (num=18)

# %% [markdown]
# ### 説明
# - 初期値 < ループ回数　かつ　break番号 < ループ回数 の場合に（break番号-初期値)分ループが繰り返され、breakが実行されます。
# - 初期値 >= ループ回数の場合、一度もループは実行されません。

# %% [markdown]
# ### 💡 練習プログラム2 ヒント
# - 減点になる方は、input()で受け取った初期値が反映されていないケースが多いです
# - それよりは少ないですが、ループ終端番号やbreak番号が反映されておらずに減点されるケースも見受けられます
#
# #### 📤　出力結果のヒント
#
# 「こちら↓にプログラムを記述しましょう」のセルの下に以下のような出力結果のサンプルがあります
#
# ```
# while開始！ (init_num=11, loop_end=25, break_num=18)
# while繰り返し中！ (num=11)
# while繰り返し中！ (num=12)
# while繰り返し中！ (num=13)
# while繰り返し中！ (num=14)
# while繰り返し中！ (num=15)
# while繰り返し中！ (num=16)
# while繰り返し中！ (num=17)
# while繰り返し中！ (num=18)
# break実行！ループを抜けます (num=18)
# while終了！ (num=18)
# ```
#
# こちらは以下の入力値の場合の出力期待値になります。
#
# ##### 🔢入力値
#
# ```
# 11 25 18
# ```
#
# 同じ入力が与えられた時の出力結果として参考になるので活用しましょう
# 消えてしまった方はGithubのソースを見ると良いでしょう

# %%
#@title 問2 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=2))
