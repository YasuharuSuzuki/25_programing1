# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/25_programing1/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📐 アルゴリズム問題
# - 2問あります

# %% [markdown]
# ## 😡 アルゴリズム問題9　激怒した  (9点)
#
# #### 📝 問題文
#
# - ゆるるくんは名作の名言を真似できるプログラムを作成中です。
# - 名前Sを入力したら、Sは激怒した！というプログラムを作成してください。
# - input()で文字列を受け取り、printで出力しましょう。

# %% [markdown]
# #### 📘 制約
#
# $ Sは20文字以下の文字列 $

# %% [markdown]
# #### 🔢 入力
# 入力は以下の形式で標準入力から与えられます
#
# ---
# $ S $
#
# ---
#
#
# ※input()１つで取得可能

# %% [markdown]
# #### 📤 出力
#
# ---
# $ S $ は激怒した！
#
# ---
#
# 名作の名言の名前を変えて出力してください。

# %% [markdown]
# ---
# ---
#
# #### 🧾 入力例1
# ---
# ```python
# ゆるるくん
# ```
# ---
#
# #### 🧪 出力例1
# ---
# ```python
# ゆるるくんは激怒した！
# ```
# ---
# ※ 激怒した文字列を出力してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🧾 入力例2
# ---
# ```python
# センチメンタル小室マイケル坂本ダダ先生
# ```
# ---
#
# #### 🧪 出力例2
# ---
# ```python
# センチメンタル小室マイケル坂本ダダ先生は激怒した！
# ```
# ---
# ※ 激怒した文字列を出力してください。

# %% [markdown]
# ---

# %% [markdown]
# ### ここ↓にPythonコードを記述してください

# %%
S = input()
print(f"{S}は激怒した！")
# Out:
# メロスは激怒した！

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/25_programing1/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# sandbox実行用
# os.symlink("../../src", ".client", target_is_directory=True)
# !bash ./sandbox_setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "12_list2/06_アルゴリズム問題.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問9 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=9, button_name="アルゴリズム問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 🎓 アルゴリズム問題10　プログラミングⅠの成績算出(10点)

# %% [markdown]
# #### 📝 問題文
# - ゆるるくんは”プログラミングⅠ”の科目を受けています。
# - この科目では、期末試験の点数Fの0.5倍が成績Rに加算されます。
# - この授業では、課題がN回あります。各課題の点数Hは0〜139点の点数が与えられ、各授業ごとの平均点数 $ \times 0.5 $ が成績Rに加算されます。
#   - 課題Hは基本は100点満点ですが、AtCoderなどのボーナス要素によって139点まで加算される可能性があります
# - $ \frac{\sum_{i=0}^{n} H_i}{n} \times 0.5 $ が50を超えることがありますが、成績Rにはそのまま加点され、Rが100を超えた場合はR=100に丸められます
# - 成績の点数Rは小数点以下切り捨てです。
# - Rが90点以上の場合は"秀"、80点以上の場合は"優"、70点以上の場合は"良"、60点以上の場合は"可"、60点未満の場合は”不可”となります。
# - ゆるるくんの成績Sを文字列で出力し、成績点Rを整数で出力してください。

# %% [markdown]
# ---
# ---
#
# #### 📘 制約
#
# $ 0 \leqq F \leqq 100 \qquad ※Fは整数 $
# $ 0 \leqq R \leqq 100 \qquad ※Rは整数 $
# $ 10 \leqq N \leqq 15 \qquad ※Nは整数 $
# $ 0 \leqq H_i \leqq 139 \qquad ※H_iは整数 $
# $ S  \qquad  ※Sは 秀、優、良、可、不可 のいずれかの文字列。  $

# %% [markdown]
# ---
# ---
#
# #### 🔢 入力
# 入力は以下の形式で標準入力から与えられます。
#
# ---
#
# $ F \quad N $
# $ H_1 \quad H_2 \quad ... \quad H_N $
#
# ---
#
# - 各値は空白区切りです

# %% [markdown]
# ---
# ---
#
# #### 📤 出力
# ---
# $ S \qquad R $
#
# ---
#
# - ゆるるくんの成績Sを 秀、優、良、可、不可のいずれかで出力し、成績Rも出力して下さい

# %% [markdown]
# ---
# ---
#
# #### 🧾 入力例1
# 標準的なケース
#
# ---
# ```
# 80 10
# 100 100 100 100 100 100 100 100 100 100
# ```
# ---
#
# #### 🧪 出力例1
# ---
# ```
# 秀 90
# ```
# ---
#
# - 期末試験: 80 × 0.5 = 40点
# - 課題平均: (100 × 10) ÷ 10 × 0.5 = 50点
# - 合計: 40 + 50 = 90点 → "秀"

# %% [markdown]
# ---
# ---
#
# #### 🧾 入力例2
# ボーナス点数ケース
#
# ---
# ```
# 70 10
# 139 139 139 139 139 139 139 139 139 139
# ```
# ---
#
# #### 🧪 出力例2
# ---
# ```
# 秀 100
# ```
# ---
#
# - 期末試験: 70 × 0.5 = 35点
# - 課題平均: (139 × 10) ÷ 10 × 0.5 = 69.5点
# - 合計: 35 + 69.5 = 104.5点 → 100点に丸められる → "秀"

# %% [markdown]
# ---
# ---
#
# #### 🧾 入力例3
# 切り捨てによる不可のケース
#
# ---
# ```
# 47 15
# 72 72 72 72 72 72 73 73 73 73 73 73 73 73 73
# ```
# ---
#
# #### 🧪 出力例3
# ---
# ```
# 不可 59
# ```
# ---
#
# - 期末試験: 47 × 0.5 = 23.5点
# - 課題平均: (72 × 6 + 73 × 9) ÷ 15 × 0.5 = 36.3点
# - 合計: 23.5 + 36.3 = 59.8点 → 59点（切り捨て） → "不可"

# %% [markdown]
# ---
# ---
#
# #### 🧾 入力例4
# 小数点以下の加算による可のケース
#
# ---
# ```
# 47 15
# 73 73 73 73 73 73 73 73 73 73 73 73 73 73 74
# ```
# ---
#
# #### 🧪 出力例4
# ---
# ```
# 可 60
# ```
# ---
#
# - 期末試験: 47 × 0.5 = 23.5点
# - 課題平均: (73 × 14 + 74) ÷ 15 × 0.5 = 36.53点
# - 合計: 23.5 + 36.53 = 60.03点 → "可"

# %% [markdown]
# ---
# ---
#
# ### ここ↓にPythonコードを記述してください

# %%
# 入力を受け取る
F, N = map(int, input().split())
H = list(map(float, input().split()))

# 期末試験の点数を計算 (0.5倍)
exam_score = F * 0.5

# 課題の平均点を計算し、0.5倍する
assignment_avg = sum(H) / N
assignment_score = assignment_avg * 0.5

# 合計点を計算（小数点以下切り捨て）
total_score = int(exam_score + assignment_score)

# 100点を超える場合は100点に丸める
if total_score > 100:
    total_score = 100

# 成績評価を判定
seiseki_kanji = ["不可","可","良","優","秀"]  # 漢字表記の成績
seiseki_boarder = [60,70,80,90]  # 各成績の境界点
grade = seiseki_kanji[0]  # デフォルトは"不可"

for i, border in enumerate(seiseki_boarder):
    if total_score >= border:
        grade = seiseki_kanji[i + 1]

# 結果を出力
print(f"{grade} {total_score}")
# Out:
# 可 60

# %%
#@title 問10 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=10, button_name="アルゴリズム問題"))
