# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/25_programing1/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01_基本文法・if文

# %% [markdown]
# ## 用語の理解を問う問題
# - 以下の問題について、正解となる選択肢を出力してください
# ※4択問題は1回目の解答のみが有効です。何度も提出することは出来ませんので、ご注意ください。

# %% [markdown]
# ---

# %% [markdown]
# ### 例題1
# - 繰り返し文（ループ文）で使用する制御文を次から選択してください
#   📕 1. loop
#   📗 2. whole
#   📘 3. for
#   📙 4. if

# %%
# 正解例
print('3')
# Out:
# 3

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題1 文字列のメソッド(3点)
# - リストに格納したすべての文字列を空白区切りで１つの文字列に連結したい。
#   最も適切なメソッドは次のどれか
#     📕 1. split()
#     📗 2. concat()
#     📘 3. append()
#     📙 4. join()

# %%
# 正解を出力してください
print('')

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/25_programing1/main/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "16_期末テスト/01_基本文法・if文.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問1 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=1, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題2 モジュール読み込み (3点)
# - mathモジュールを m という別名で読み込む 正しい方法を次から選びなさい
#     📕 1. import math as m
#     📗 2. import m = math
#     📘 3. from math import m
#     📙 4. import m from math

# %%
# 正解を出力してください
print('')

# %%
#@title 問2 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=2, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🎲 四択問題3 インデント (3点)
#
# - インデントが必要となるコード構造を次から選べ
#     📕 1. 変数への代入
#     📗 2. import文
#     📘 3. print文の使用
#     📙 4. if文のコードブロック

# %%
# 正解を出力してください
print('')

# %%
#@title 問3 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=3, button_name="四択問題"))

# %% [markdown]
# ---
# ---
# ---
# ---
# ---
# ## アルゴリズム問題

# %% [markdown]
# ### 🚌 🚕 アルゴリズム問題4 バス or タクシー (10点)
#
# #### 📝 問題文
#
# - ゆるるくんは友達と隣街にお出かけしようとしています。
# - 合計 $ N $ 名で移動しますが、タクシーですと $ C_{taxi} $ 円、バスですと一人あたり $ C_{bus} $ 円掛かります。
# - ゆるるくんはバスかタクシーのどちらの方が安上がりかを知りたいです。
# - バスの方が安い時は "バスで行く"、タクシーの方が安い時は "タクシーで行く"、同じ値段の時は "どちらも同じ" と出力してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 📘 制約
#
# $ 2 \leq　N \leq　4 $
# $ 1 \leq　C_{taxi} \leq　2500 $
# $ 1 \leq　C_{bus} \leq　660 $
# $ N $、$ C_{taxi} $、$ C_{bus} $ はそれぞれ整数

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🔢 入力
#
# 入力は以下の形式で標準入力から与えられます
#
# ---
# $
# N \quad C_{taxi} \quad C_{bus} \\
# $
#
#
# ---

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 📤 出力
#
# ---
#
# "バスで行く" or "タクシーで行く" or "どちらも同じ"
#
# ---
#
# バスで行くのかタクシーで行くのか、それともどちらも同じ金額かを出力してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🧾 入力例1
# ---
# ```python
# 3 2500 660
# ```
# ---
#
# #### 🧪 出力例1
# ---
# ```python
# バスで行く
# ```
# ---
#
# - バスのほうが金額が安いため、”バスで行く”と出力してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🧾 入力例2
#
# ---
# ```python
# 4 1600 550
# ```
# ---
#
# #### 🧪 出力例2
# ---
# ```python
# タクシーで行く
# ```
# ---
#
# - タクシーのほうが金額が安いため、”タクシーで行く”と出力してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 🧾 入力例3
#
# ---
# ```python
# 2 1200 600
# ```
# ---
#
# #### 🧪 出力例3
# ---
# ```python
# どちらも同じ
# ```
# ---
#
# - どちらも同じ金額のため、”どちらも同じ”と出力してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### ここ↓にPythonコードを記述してください

# %%
# Out:
# バスで行く

# %%
#@title 問4 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=4, button_name="アルゴリズム問題"))

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ### 🛫 アルゴリズム問題5 ゆるる航空の乗車料金 (10点)
#
# #### 📝 問題文
#
# - ゆるるくんは航空会社を初めました
# - 運行区間は都心部からの観光客の多い羽田＝沖縄間と羽田＝札幌間です
# - ゆるる航空では、運賃を共通化することでわかりやすさを売りの１つにすることにしました
# - 3種類の便 ( プレミアム便, 通常便, 深夜便 ) があり、それぞれの基本料金が設定されています。
# - また、3種類の座席クラス ( ファーストクラス, ビジネスクラス, エコノミークラス ) があり、基本料金に対して以下の倍率が掛かります。
#
#
# ##### 座席クラス料金
# - ファーストクラス: 基本料金の2.5倍
# - ビジネスクラス: 基本料金の1.5倍
# - エコノミークラス: 基本料金そのまま（1倍）
#
# ##### 便の種類による基本料金（エコノミークラス料金）
# - プレミアム便: 40000円
# - 通常便: 30000円
# - 深夜便: 20000円
#
# - 入力として便のタイプ $ S $ と、座席クラス $ T $ が渡されます。
# - 料金を出力するプログラムを作成してください。

# %% [markdown]
# ---
# ---

# %% [markdown]
# #### 📘 制約
#
# $ Sは「プレミアム便」「通常便」「深夜便」のいずれか $
# $ Tは「ファーストクラス」「ビジネスクラス」「エコノミークラス」のいずれか $
# $ 運賃は整数 $

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### 🔢 入力
# 入力は以下の形式で標準入力から与えられます
#
# ---
# $ S \quad T $
#
# ---
#
# - S は便の種類を表す文字列 ( プレミアム便, 通常便, 深夜便 )
# - T は座席クラスを表す文字列 ( ファーストクラス, ビジネスクラス, エコノミークラス )

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### 📤 出力
#
#
# ---
# 運賃
#
# ---
#
# 運賃を整数で出力してください

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### 🧾 入力例1
# ---
# $ プレミアム便 \quad ファーストクラス $
#
# ---
#
# ### 🧪 出力例1
# ---
# ```python
# 10000
# ```
# ---
#
# - プレミアム便は40000円、ファーストクラスは基本料金の2.5倍です
# - 40000ｘ2.5＝100,000円となります

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### 🧾 入力例2
# ---
# $ 深夜便 \quad エコノミークラス $
#
# ---
#
# ### 🧪 出力例2
# ---
# ```python
# 20000
# ```
# ---
#
# - 深夜便は20000円、エコノミークラスは基本料金のまま（1倍）です
# - 20000ｘ1.0＝20,000円となります

# %% [markdown]
# ---
# ---
# ### ここ↓にPythonコードを記述してください

# %%
# Out:
# 60000

# %%
#@title 問5 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=5, button_name="アルゴリズム問題"))
