# %% [markdown]
# <a href="https://colab.research.google.com/github/YasuharuSuzuki/25_programing1/blob/main/" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Section 7-1 for文の基本とbreak
# 処理を繰り返すfor文と、ループを抜けるbreak

# %% [markdown]
# ## for文 参考サイト
# ### [参考サイト1 【Python早見表】 for文（反復処理）](https://chokkan.github.io/python/03control.html#for)
# - for文、continue文、break文、for-else文が簡単にわかりやすく説明されています。
#
# ### [参考サイト2 【Python入門】for文による繰り返し](https://utokyo-ipp.github.io/3/3-2.html#for%E6%96%87%E3%81%AB%E3%82%88%E3%82%8B%E7%B9%B0%E3%82%8A%E8%BF%94%E3%81%97)
# - こちらはfor文を中心に解説されています。練習問題もあります。

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## for文
# ### for文とは？
# - 条件に応じて繰り返し処理を実行するにはfor文も使うことができます。
# - [Python早見表の説明](https://chokkan.github.io/python/03control.html#for)
# - 前回学んだwhile文も同じ繰り返し処理ですが、私はfor文の方をよく使います。
#   - 繰り返し回数が明確になっている処理（AIの学習用画像の一括読み込みや、AIの学習処理など）はfor文を使うことが多いです。
#   - 繰り返し回数が明確になっていない処理ではwhileを使用することがあります。

# %% [markdown]
# ---

# %% [markdown]
# ## サンプルプログラム1　for文
# - 5回繰り返すプログラムをfor文で書くと以下のようになります

# %%
print("for開始！")
for count in range(5):
    print(f"for繰り返し中！ (count={count})")
print("for終了！")
# Out:
# for開始！
# for繰り返し中！ (count=0)
# for繰り返し中！ (count=1)
# for繰り返し中！ (count=2)
# for繰り返し中！ (count=3)
# for繰り返し中！ (count=4)
# for終了！

# %% [markdown]
# ### 説明
# - ```for開始!``` でプログラムを開始しています
# - countが5になるまでの間、```for繰り返し中！``` が実行されます。
# - countが5になると条件が満たされなくなり、forループを抜けて ```for終了！``` と表示されます
# - 上記のように、単純な繰り返し処理ならwhile文よりもスッキリ書けます
# - range()は初期値やステップを指定することが出来ます。
#   - range(初期値、終了値)と渡すと、初期値から終了値-1までカウントアップします。range(2,5)と書くと2,3,4とcountに値が代入されす
#   - range(初期値、終了値、ステップ)と渡すと、初期値から終了値-1までステップずつカウントアップします。range(3,10,2)と書くと3,5,7,9とcountに値が代入されます

# %% [markdown]
# ---

# %% [markdown]
# ## 練習プログラム1 (10点)
# - input()でループ回数を数字で受け取り、その回数分ループするプログラムを作成しましょう
#   - 最初に```for開始！ (loop_count=n)``` と出力します。ループ回数も表示しましょう。（nのところは実際のループ数）
#   - ループしている間、```for繰り返し中！ (count=n)``` を出力します。（nのところは実際のループした回数）
#   - ループが終わったら ```for終了！``` と表示しましょう。
# - サンプルプログラム１をベースに開始や繰り返し中、終了などを表示します

# %%
loop_count = int(input())
print(f"for開始！ (loop_count={loop_count})")
for count in range(loop_count):
    print(f"for繰り返し中！ (count={count})")
print("for終了！")
# Out:
# 7
# for開始！ (loop_count=7)
# for繰り返し中！ (count=0)
# for繰り返し中！ (count=1)
# for繰り返し中！ (count=2)
# for繰り返し中！ (count=3)
# for繰り返し中！ (count=4)
# for繰り返し中！ (count=5)
# for繰り返し中！ (count=6)
# for終了！

# %% [markdown]
# ### 動作確認
# - 最初にinputでループ回数を取得します。
# - ```for開始! (loop_count=n)``` でプログラムを開始します。その時にループ回数も表示しましょう
# - ループしている間、```for繰り返し中！(count=n)``` が実行されます。
# - ループが終わると ```for終了！``` と表示されます
# - ループ回数にマイナス値を入力すると１回も実行されないことも確認してみましょう
# - 1万など大きな値を入力すると実行に時間がかかることも確認しましょう（計算量を意識しましょう）

# %%
#@title 送信処理用共通プログラム（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown 解答の送信に必要です。（中身は絶対に修正しないでください）

import os
os.makedirs(".client/python", exist_ok=True)  # 隠しフォルダを作成
# !wget -q https://raw.githubusercontent.com/YasuharuSuzuki/25_programing1/feature/add_class01/91_notebook_client/src/setup.sh -O .client/setup.sh   # 外部コードをダウンロードして隠しフォルダに配置
# !chmod +x ./.client/setup.sh
# !bash ./.client/setup.sh # 実行

# sandbox実行用
# os.symlink("../../src", ".client", target_is_directory=True)
# !bash ./sandbox_setup.sh # 実行

# モジュールの初期化
exec(open('.client/client_setup.py').read())

# ノートブック固有の設定
NOTEBOOK_PATH = "07_for文/01_for文の基本とbreak.ipynb"
set_notebook_config(NOTEBOOK_PATH)

# %%
#@title 問1 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=1))

# %% [markdown]
# ---

# %% [markdown]
# ## サンプルプログラム2
# - for文では in の後ろにリストを渡すと、そのリストが終わるまでループすることが出来ます
# - ```["blue","pink","green","red"]``` というリストを宣言し、ループしてみましょう
#   - リストとは、複数の値を格納可能な形式です（リストについては後の章で詳しく扱います）
# - リストを作成するには、リストを構成する要素をコンマで区切り全体をかぎ括弧 ```[...]``` で囲みます。

# %%
colors = ["blue","pink","green","red"]
print("for開始！")
for color in colors:
    print(f"for繰り返し中！ (color={color})")
print("for終了！")
# Out:
# for開始！
# for繰り返し中！ (color=blue)
# for繰り返し中！ (color=pink)
# for繰り返し中！ (color=green)
# for繰り返し中！ (color=red)
# for終了！

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## 練習プログラム2 (10点)
# - `["春","夏","秋","冬"]` というリストを宣言し、サンプルプログラム2をベースに開始や繰り返し中、終了などを出力してみましょう
#   - 最初に```for開始！``` と出力します。
#   - ループ回数になるまでの間、```for繰り返し中！ (season=s)``` を出力します。（sのところは季節を表す文字）
#   - ループが終わったら ```for終了！``` と表示しましょう。

# %%
seasons = ["春","夏","秋","冬"]
print("for開始！")
for season in seasons:
    print(f"for繰り返し中！ (season={season})")
print("for終了！")
# Out:
# for開始！
# for繰り返し中！ (season=春)
# for繰り返し中！ (season=夏)
# for繰り返し中！ (season=秋)
# for繰り返し中！ (season=冬)
# for終了！

# %%
#@title 問2 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=2))

# %% [markdown]
# ---

# %% [markdown]
# ## break文
# - while文同様にfor文による繰り返し実行中にbreak文を実行すると、以降の処理を実行せずに繰り返しを終了します。
# - 終了条件をループ文中に好きなだけ追加できるため、よく使用します。

# %% [markdown]
# ## サンプルプログラム3
# - 変数 `num` を `2` で初期化し、forループで `1` ずつカウントアップします。
# - for文の途中のif文で、`num` 変数が `6` 以上になるかどうかを確認しています
# - `num` が `6` になるとbreak文を実行し、繰り返しを終了します

# %%
print("for開始！")
for num in range(2,10):
    print(f"for繰り返し中！ (num={num})")
    if num >= 6:
        print(f"break実行！ループを抜けます (num={num})")
        break
print(f"for終了！(num={num})")
# Out:
# for開始！
# for繰り返し中！ (num=2)
# for繰り返し中！ (num=3)
# for繰り返し中！ (num=4)
# for繰り返し中！ (num=5)
# for繰り返し中！ (num=6)
# break実行！ループを抜けます (num=6)
# for終了！(num=6)

# %% [markdown]
# ### 説明
# - `for開始!` でプログラムを開始しています
# - `for num in range(2,10)` と宣言することで、初期値が `2`で、`10` の直前までの間ループが実行されます。
# - ループしている間 `for繰り返し中！ (num=n)` が実行されます。
# - `num` が `6` になるとif文の中が実行され、`break実行！ループを抜けます (num=n)` と表示したあと<b>break文を実行</b>してループを抜けます。
# - forループを抜けたあと `for終了！ (num=n)` と表示します。

# %% [markdown]
# ---

# %% [markdown]
# ## 練習プログラム3 (10点)
# - input()で初期値、ループ終端番号、break番号を空白区切りで受け取り、サンプルプログラム３のように表示するプログラムを作成してみましょう
#   - 最初に`for開始！ (init_num=n, loop_end=n, break_num=n)` と出力します。初期値とループ終端番号、break番号も表示しましょう。（nは実際の初期値とループ終端番号とbreak番号）
#   - `num` がループ終端番号になるまでの間、`for繰り返し中！ (num=n)` を出力します。（nは現在の数値）
#   - `num` が `break_num` になるとif文の中が実行され、`break実行！ループを抜けます (num=n)` と表示したあと<b>break文を実行</b>してループを抜けましょう。
#   - `num` がループ終端番号に達するとループ条件が満たされなくなり、whileループを抜けます。
#   - while条件を満たさなくなった場合、またはbreak文によりwhileループを抜けたら、 `for終了！ (num=n)` と表示しましょう。

# %% [markdown]
# #### こちら↓にプログラムを記述しましょう

# %%
init_num, loop_end, break_num = map(int,input().split())
print(f"for開始！ (init_num={init_num}, loop_end={loop_end}, break_num={break_num})")
for num in range(init_num, loop_end):
    print(f"for繰り返し中！ (num={num})")
    if num >= break_num:
        print(f"break実行！ループを抜けます (num={num})")
        break

print(f"for終了！ (num={num})")
# Out:
# for開始！ (init_num=6, loop_end=13, break_num=10)
# for繰り返し中！ (num=6)
# for繰り返し中！ (num=7)
# for繰り返し中！ (num=8)
# for繰り返し中！ (num=9)
# for繰り返し中！ (num=10)
# break実行！ループを抜けます (num=10)
# for終了！ (num=10)

# %% [markdown]
# ### 説明
# - 初期値 <= ループ番号　かつ　break番号 < ループ番号 の場合に（break番号-初期値)分ループが繰り返され、breakが実行されます。
# - 初期値 >= ループ終端番号 の場合、一度もループは実行されません。

# %% [markdown]
# ### 💡 練習プログラム3 ヒント
# - 減点になる方は、input()で受け取った初期値が反映されていないケースが多いです
# - 初期値はrangeで指定できます([参考 : Python早見表 - for文（反復処理）](https://chokkan.github.io/python/03control.html#for))
# - それよりは少ないですが、ループ終端番号やbreak番号が反映されておらずに減点されるケースも見受けられます
#
# #### 📤 出力結果のヒント
#
# 「こちら↓にプログラムを記述しましょう」のセルの下に以下のような出力結果のサンプルがあります
#
# ```
# for開始！ (init_num=6, loop_end=13, break_num=10)
# for繰り返し中！ (num=6)
# for繰り返し中！ (num=7)
# for繰り返し中！ (num=8)
# for繰り返し中！ (num=9)
# for繰り返し中！ (num=10)
# break実行！ループを抜けます (num=10)
# for終了！ (num=10)
# ```
#
# こちらは以下の入力値の場合の出力期待値になります。
#
# ##### 🔢 入力値
#
# ```
# 6 13 10
# ```
#
# 同じ入力が与えられた時の出力結果として参考になるので活用しましょう
# 消えてしまった方はGithubのソースを見ると良いでしょう

# %%
#@title 問3 送信ボタン表示（以下のセルを「▶ 実行」して下さい。） { display-mode: "form" }
#@markdown メールアドレスを取得して、送信ボタンを押してください（中のプログラムは絶対に修正しないでください）
display(create_submit_button(problem_number=3))
